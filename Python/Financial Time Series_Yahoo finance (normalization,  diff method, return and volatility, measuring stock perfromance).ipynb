# %% [markdown]
# # Managing Time Series Data With Pandas

# %% [markdown]
# ## Time Series Advanced / Financial Data

# %% [markdown]
# ### Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
ticker = ["AAPL", "SBUX", "KO", "MMM", "VZ", "O" ]
#Apple, starbucks, Coca-cola, 3M, Verizon, Realty income

# %%
stocks = yf.download("AAPL", start = "2010-01-01", end = "2022-12-27")
stocks
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.515213
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.526477
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.422665
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.410791
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.453412
# ...                ...         ...         ...         ...         ...
# 2022-12-19  135.110001  135.199997  131.320007  132.369995  132.369995
# 2022-12-20  131.389999  133.250000  129.889999  132.300003  132.300003
# 2022-12-21  132.979996  136.809998  132.750000  135.449997  135.449997
# 2022-12-22  134.350006  134.559998  130.300003  132.229996  132.229996
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
#
#                Volume
# Date
# ...

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2022-12-27")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks
# Out:
#              Adj Close                                               \
#                   AAPL         KO         MMM          O       SBUX
# Date
# 2010-01-04    6.515213  19.081617   57.456108  13.955854   9.256215
# 2010-01-05    6.526477  18.850788   57.096233  14.191124   9.473064
# 2010-01-06    6.422664  18.844101   57.905975  14.180435   9.404797
# 2010-01-07    6.410790  18.797266   57.947491  14.479868   9.380708
# 2010-01-08    6.453413  18.449356   58.355816  14.677710   9.348579
# ...                ...        ...         ...        ...        ...
# 2022-12-19  132.369995  62.840000  122.129997  63.540001  98.300003
# 2022-12-20  132.300003  62.790001  120.809998  63.110001  98.000000
# 2022-12-21  135.449997  63.799999  123.459999  64.239998  98.669998
# 2022-12-22  132.229996  63.340000  121.589996  63.450001  97.760002
# 2022-12-23  131.860001  63.820000  120.139999  64.410004  98.269997
#
#                             Close                                    ...  \
# ...

# %%
stocks.head()
# Out:
#            Adj Close                                                        \
#                 AAPL         KO        MMM          O      SBUX         VZ
# Date
# 2010-01-04  6.515213  19.081617  57.456108  13.955854  9.256215  16.828812
# 2010-01-05  6.526477  18.850788  57.096233  14.191124  9.473064  16.859154
# 2010-01-06  6.422664  18.844101  57.905975  14.180435  9.404797  16.374384
# 2010-01-07  6.410790  18.797266  57.947491  14.479868  9.380708  16.276928
# 2010-01-08  6.453413  18.449356  58.355816  14.677710  9.348579  16.287186
#
#                Close                                   ...       Open  \
#                 AAPL         KO        MMM          O  ...        MMM
# Date                                                   ...
# 2010-01-04  7.643214  28.520000  83.019997  25.290697  ...  83.089996
# 2010-01-05  7.656429  28.174999  82.500000  25.717054  ...  82.800003
# 2010-01-06  7.534643  28.165001  83.669998  25.697674  ...  83.879997
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                                               \
#                   AAPL         KO         MMM          O       SBUX
# Date
# 2022-12-19  132.369995  62.840000  122.129997  63.540001  98.300003
# 2022-12-20  132.300003  62.790001  120.809998  63.110001  98.000000
# 2022-12-21  135.449997  63.799999  123.459999  64.239998  98.669998
# 2022-12-22  132.229996  63.340000  121.589996  63.450001  97.760002
# 2022-12-23  131.860001  63.820000  120.139999  64.410004  98.269997
#
#                             Close                                    ...  \
#                    VZ        AAPL         KO         MMM          O  ...
# Date                                                                 ...
# 2022-12-19  37.029999  132.369995  62.840000  122.129997  63.540001  ...
# 2022-12-20  36.990002  132.300003  62.790001  120.809998  63.110001  ...
# 2022-12-21  37.779999  135.449997  63.799999  123.459999  64.239998  ...
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3268 entries, 2010-01-04 to 2022-12-23
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3268 non-null   float64
#  1   (Adj Close, KO)    3268 non-null   float64
#  2   (Adj Close, MMM)   3268 non-null   float64
#  3   (Adj Close, O)     3268 non-null   float64
#  4   (Adj Close, SBUX)  3268 non-null   float64
#  5   (Adj Close, VZ)    3268 non-null   float64
#  6   (Close, AAPL)      3268 non-null   float64
#  7   (Close, KO)        3268 non-null   float64
#  8   (Close, MMM)       3268 non-null   float64
#  9   (Close, O)         3268 non-null   float64
#  10  (Close, SBUX)      3268 non-null   float64
#  11  (Close, VZ)        3268 non-null   float64
#  12  (High, AAPL)       3268 non-null   float64
#  13  (High, KO)         3268 non-null   float64
#  14  (High, MMM)        3268 non-null   float64
# ...

# %%
stocks.to_csv("stocks.csv")

# %%
pd.read_csv('stocks.csv')
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 MMM
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04  6.5152130126953125   19.08161735534668   57.45610809326172
# 3     2010-01-05   6.526476860046387  18.850788116455078   57.09623336791992
# 4     2010-01-06   6.422664165496826  18.844100952148438  57.905975341796875
# ...          ...                 ...                 ...                 ...
# 3265  2022-12-19   132.3699951171875   62.84000015258789  122.12999725341797
# 3266  2022-12-20   132.3000030517578  62.790000915527344  120.80999755859375
# 3267  2022-12-21   135.4499969482422   63.79999923706055  123.45999908447266
# 3268  2022-12-22  132.22999572753906   63.34000015258789  121.58999633789062
# 3269  2022-12-23  131.86000061035156   63.81999969482422  120.13999938964844
#
# ...

# %%
pd.read_csv("stocks.csv", header = None)
# Out:
#               0                   1                   2                   3   \
# 0            NaN           Adj Close           Adj Close           Adj Close
# 1            NaN                AAPL                  KO                 MMM
# 2           Date                 NaN                 NaN                 NaN
# 3     2010-01-04  6.5152130126953125   19.08161735534668   57.45610809326172
# 4     2010-01-05   6.526476860046387  18.850788116455078   57.09623336791992
# ...          ...                 ...                 ...                 ...
# 3266  2022-12-19   132.3699951171875   62.84000015258789  122.12999725341797
# 3267  2022-12-20   132.3000030517578  62.790000915527344  120.80999755859375
# 3268  2022-12-21   135.4499969482422   63.79999923706055  123.45999908447266
# 3269  2022-12-22  132.22999572753906   63.34000015258789  121.58999633789062
# 3270  2022-12-23  131.86000061035156   63.81999969482422  120.13999938964844
#
# ...

# %%
pd.read_csv("stocks.csv", header = 0)
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 MMM
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04  6.5152130126953125   19.08161735534668   57.45610809326172
# 3     2010-01-05   6.526476860046387  18.850788116455078   57.09623336791992
# 4     2010-01-06   6.422664165496826  18.844100952148438  57.905975341796875
# ...          ...                 ...                 ...                 ...
# 3265  2022-12-19   132.3699951171875   62.84000015258789  122.12999725341797
# 3266  2022-12-20   132.3000030517578  62.790000915527344  120.80999755859375
# 3267  2022-12-21   135.4499969482422   63.79999923706055  123.45999908447266
# 3268  2022-12-22  132.22999572753906   63.34000015258789  121.58999633789062
# 3269  2022-12-23  131.86000061035156   63.81999969482422  120.13999938964844
#
# ...

# %%
pd.read_csv("stocks.csv", header = 1)
# Out:
#       Unnamed: 0        AAPL         KO         MMM          O       SBUX  \
# 0           Date         NaN        NaN         NaN        NaN        NaN
# 1     2010-01-04    6.515213  19.081617   57.456108  13.955854   9.256215
# 2     2010-01-05    6.526477  18.850788   57.096233  14.191124   9.473064
# 3     2010-01-06    6.422664  18.844101   57.905975  14.180435   9.404797
# 4     2010-01-07    6.410790  18.797266   57.947491  14.479868   9.380708
# ...          ...         ...        ...         ...        ...        ...
# 3264  2022-12-19  132.369995  62.840000  122.129997  63.540001  98.300003
# 3265  2022-12-20  132.300003  62.790001  120.809998  63.110001  98.000000
# 3266  2022-12-21  135.449997  63.799999  123.459999  64.239998  98.669998
# 3267  2022-12-22  132.229996  63.340000  121.589996  63.450001  97.760002
# 3268  2022-12-23  131.860001  63.820000  120.139999  64.410004  98.269997
#
#              VZ      AAPL.1       KO.1       MMM.1  ...       MMM.4  \
# ...

# %%
pd.read_csv("stocks.csv", header = 2) #NaN
# Out:
#             Date  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     2010-01-04    6.515213   19.081617   57.456108   13.955854    9.256215
# 1     2010-01-05    6.526477   18.850788   57.096233   14.191124    9.473064
# 2     2010-01-06    6.422664   18.844101   57.905975   14.180435    9.404797
# 3     2010-01-07    6.410790   18.797266   57.947491   14.479868    9.380708
# 4     2010-01-08    6.453413   18.449356   58.355816   14.677710    9.348579
# ...          ...         ...         ...         ...         ...         ...
# 3263  2022-12-19  132.369995   62.840000  122.129997   63.540001   98.300003
# 3264  2022-12-20  132.300003   62.790001  120.809998   63.110001   98.000000
# 3265  2022-12-21  135.449997   63.799999  123.459999   64.239998   98.669998
# 3266  2022-12-22  132.229996   63.340000  121.589996   63.450001   97.760002
# 3267  2022-12-23  131.860001   63.820000  120.139999   64.410004   98.269997
#
# ...

# %%
pd.read_csv("stocks.csv", header = [0, 1]) #multi-index of 'header = 0' and 'header = 1'
# Out:
#      Unnamed: 0_level_0   Adj Close                                    \
#      Unnamed: 0_level_1        AAPL         KO         MMM          O
# 0                  Date         NaN        NaN         NaN        NaN
# 1            2010-01-04    6.515213  19.081617   57.456108  13.955854
# 2            2010-01-05    6.526477  18.850788   57.096233  14.191124
# 3            2010-01-06    6.422664  18.844101   57.905975  14.180435
# 4            2010-01-07    6.410790  18.797266   57.947491  14.479868
# ...                 ...         ...        ...         ...        ...
# 3264         2022-12-19  132.369995  62.840000  122.129997  63.540001
# 3265         2022-12-20  132.300003  62.790001  120.809998  63.110001
# 3266         2022-12-21  135.449997  63.799999  123.459999  64.239998
# 3267         2022-12-22  132.229996  63.340000  121.589996  63.450001
# 3268         2022-12-23  131.860001  63.820000  120.139999  64.410004
#
# ...

# %%
pd.read_csv("stocks.csv", header = [0, 1], index_col = [0]) #Date index by 'index_col = [0]'
# Out:
#              Adj Close                                               \
#                   AAPL         KO         MMM          O       SBUX
# Date
# 2010-01-04    6.515213  19.081617   57.456108  13.955854   9.256215
# 2010-01-05    6.526477  18.850788   57.096233  14.191124   9.473064
# 2010-01-06    6.422664  18.844101   57.905975  14.180435   9.404797
# 2010-01-07    6.410790  18.797266   57.947491  14.479868   9.380708
# 2010-01-08    6.453413  18.449356   58.355816  14.677710   9.348579
# ...                ...        ...         ...        ...        ...
# 2022-12-19  132.369995  62.840000  122.129997  63.540001  98.300003
# 2022-12-20  132.300003  62.790001  120.809998  63.110001  98.000000
# 2022-12-21  135.449997  63.799999  123.459999  64.239998  98.669998
# 2022-12-22  132.229996  63.340000  121.589996  63.450001  97.760002
# 2022-12-23  131.860001  63.820000  120.139999  64.410004  98.269997
#
#                             Close                                    ...  \
# ...

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0]) #parsing the date index
stocks
# Out:
#              Adj Close                                               \
#                   AAPL         KO         MMM          O       SBUX
# Date
# 2010-01-04    6.515213  19.081617   57.456108  13.955854   9.256215
# 2010-01-05    6.526477  18.850788   57.096233  14.191124   9.473064
# 2010-01-06    6.422664  18.844101   57.905975  14.180435   9.404797
# 2010-01-07    6.410790  18.797266   57.947491  14.479868   9.380708
# 2010-01-08    6.453413  18.449356   58.355816  14.677710   9.348579
# ...                ...        ...         ...        ...        ...
# 2022-12-19  132.369995  62.840000  122.129997  63.540001  98.300003
# 2022-12-20  132.300003  62.790001  120.809998  63.110001  98.000000
# 2022-12-21  135.449997  63.799999  123.459999  64.239998  98.669998
# 2022-12-22  132.229996  63.340000  121.589996  63.450001  97.760002
# 2022-12-23  131.860001  63.820000  120.139999  64.410004  98.269997
#
#                             Close                                    ...  \
# ...

# %%
pd.read_csv("stocks.csv", index_col = [0])
# Out:
#                      Adj Close         Adj Close.1         Adj Close.2  \
# NaN                       AAPL                  KO                 MMM
# Date                       NaN                 NaN                 NaN
# 2010-01-04  6.5152130126953125   19.08161735534668   57.45610809326172
# 2010-01-05   6.526476860046387  18.850788116455078   57.09623336791992
# 2010-01-06   6.422664165496826  18.844100952148438  57.905975341796875
# ...                        ...                 ...                 ...
# 2022-12-19   132.3699951171875   62.84000015258789  122.12999725341797
# 2022-12-20   132.3000030517578  62.790000915527344  120.80999755859375
# 2022-12-21   135.4499969482422   63.79999923706055  123.45999908447266
# 2022-12-22  132.22999572753906   63.34000015258789  121.58999633789062
# 2022-12-23  131.86000061035156   63.81999969482422  120.13999938964844
#
#                    Adj Close.3        Adj Close.4         Adj Close.5  \
# ...

# %%
stocks.info() #DatetimeIndex
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3268 entries, 2010-01-04 to 2022-12-23
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3268 non-null   float64
#  1   (Adj Close, KO)    3268 non-null   float64
#  2   (Adj Close, MMM)   3268 non-null   float64
#  3   (Adj Close, O)     3268 non-null   float64
#  4   (Adj Close, SBUX)  3268 non-null   float64
#  5   (Adj Close, VZ)    3268 non-null   float64
#  6   (Close, AAPL)      3268 non-null   float64
#  7   (Close, KO)        3268 non-null   float64
#  8   (Close, MMM)       3268 non-null   float64
#  9   (Close, O)         3268 non-null   float64
#  10  (Close, SBUX)      3268 non-null   float64
#  11  (Close, VZ)        3268 non-null   float64
#  12  (High, AAPL)       3268 non-null   float64
#  13  (High, KO)         3268 non-null   float64
#  14  (High, MMM)        3268 non-null   float64
# ...

# %%
pd.read_csv("stocks.csv", header = [0, 1])
# Out:
#      Unnamed: 0_level_0   Adj Close                                    \
#      Unnamed: 0_level_1        AAPL         KO         MMM          O
# 0                  Date         NaN        NaN         NaN        NaN
# 1            2010-01-04    6.515213  19.081617   57.456108  13.955854
# 2            2010-01-05    6.526477  18.850788   57.096233  14.191124
# 3            2010-01-06    6.422664  18.844101   57.905975  14.180435
# 4            2010-01-07    6.410790  18.797266   57.947491  14.479868
# ...                 ...         ...        ...         ...        ...
# 3264         2022-12-19  132.369995  62.840000  122.129997  63.540001
# 3265         2022-12-20  132.300003  62.790001  120.809998  63.110001
# 3266         2022-12-21  135.449997  63.799999  123.459999  64.239998
# 3267         2022-12-22  132.229996  63.340000  121.589996  63.450001
# 3268         2022-12-23  131.860001  63.820000  120.139999  64.410004
#
# ...

# %%
stocks.head()
# Out:
#            Adj Close                                                        \
#                 AAPL         KO        MMM          O      SBUX         VZ
# Date
# 2010-01-04  6.515213  19.081617  57.456108  13.955854  9.256215  16.828812
# 2010-01-05  6.526477  18.850788  57.096233  14.191124  9.473064  16.859154
# 2010-01-06  6.422664  18.844101  57.905975  14.180435  9.404797  16.374384
# 2010-01-07  6.410790  18.797266  57.947491  14.479868  9.380708  16.276928
# 2010-01-08  6.453413  18.449356  58.355816  14.677710  9.348579  16.287186
#
#                Close                                   ...       Open  \
#                 AAPL         KO        MMM          O  ...        MMM
# Date                                                   ...
# 2010-01-04  7.643214  28.520000  83.019997  25.290697  ...  83.089996
# 2010-01-05  7.656429  28.174999  82.500000  25.717054  ...  82.800003
# 2010-01-06  7.534643  28.165001  83.669998  25.697674  ...  83.879997
# ...

# %%
stocks.columns.to_flat_index() #index flattening
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'MMM'),
#           ('Adj Close', 'O'), ('Adj Close', 'SBUX'),   ('Adj Close', 'VZ'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'MMM'),
#               ('Close', 'O'),     ('Close', 'SBUX'),       ('Close', 'VZ'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'MMM'),
#                ('High', 'O'),      ('High', 'SBUX'),        ('High', 'VZ'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'MMM'),
#                 ('Low', 'O'),       ('Low', 'SBUX'),         ('Low', 'VZ'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'MMM'),
#                ('Open', 'O'),      ('Open', 'SBUX'),        ('Open', 'VZ'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'MMM'),
#              ('Volume', 'O'),    ('Volume', 'SBUX'),      ('Volume', 'VZ')],
#       dtype='object')

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'MMM'),
#           ('Adj Close', 'O'), ('Adj Close', 'SBUX'),   ('Adj Close', 'VZ'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'MMM'),
#               ('Close', 'O'),     ('Close', 'SBUX'),       ('Close', 'VZ'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'MMM'),
#                ('High', 'O'),      ('High', 'SBUX'),        ('High', 'VZ'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'MMM'),
#                 ('Low', 'O'),       ('Low', 'SBUX'),         ('Low', 'VZ'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'MMM'),
#                ('Open', 'O'),      ('Open', 'SBUX'),        ('Open', 'VZ'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'MMM'),
#              ('Volume', 'O'),    ('Volume', 'SBUX'),      ('Volume', 'VZ')],
#       dtype='object')

# %%
stocks.head() #flattend column index
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, MMM)  \
# Date
# 2010-01-04           6.515213        19.081617         57.456108
# 2010-01-05           6.526477        18.850788         57.096233
# 2010-01-06           6.422664        18.844101         57.905975
# 2010-01-07           6.410790        18.797266         57.947491
# 2010-01-08           6.453413        18.449356         58.355816
#
#             (Adj Close, O)  (Adj Close, SBUX)  (Adj Close, VZ)  (Close, AAPL)  \
# Date
# 2010-01-04       13.955854           9.256215        16.828812       7.643214
# 2010-01-05       14.191124           9.473064        16.859154       7.656429
# 2010-01-06       14.180435           9.404797        16.374384       7.534643
# 2010-01-07       14.479868           9.380708        16.276928       7.520714
# 2010-01-08       14.677710           9.348579        16.287186       7.570714
#
#             (Close, KO)  (Close, MMM)  (Close, O)  ...  (Open, MMM)  \
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns) #going back to multi-index

# %%
stocks.head()
# Out:
#            Adj Close                                                        \
#                 AAPL         KO        MMM          O      SBUX         VZ
# Date
# 2010-01-04  6.515213  19.081617  57.456108  13.955854  9.256215  16.828812
# 2010-01-05  6.526477  18.850788  57.096233  14.191124  9.473064  16.859154
# 2010-01-06  6.422664  18.844101  57.905975  14.180435  9.404797  16.374384
# 2010-01-07  6.410790  18.797266  57.947491  14.479868  9.380708  16.276928
# 2010-01-08  6.453413  18.449356  58.355816  14.677710  9.348579  16.287186
#
#                Close                                   ...       Open  \
#                 AAPL         KO        MMM          O  ...        MMM
# Date                                                   ...
# 2010-01-04  7.643214  28.520000  83.019997  25.290697  ...  83.089996
# 2010-01-05  7.656429  28.174999  82.500000  25.717054  ...  82.800003
# 2010-01-06  7.534643  28.165001  83.669998  25.697674  ...  83.879997
# ...

# %%
stocks.swaplevel(axis = 1) #index level swap
# Out:
#                   AAPL         KO         MMM          O       SBUX  \
#              Adj Close  Adj Close   Adj Close  Adj Close  Adj Close
# Date
# 2010-01-04    6.515213  19.081617   57.456108  13.955854   9.256215
# 2010-01-05    6.526477  18.850788   57.096233  14.191124   9.473064
# 2010-01-06    6.422664  18.844101   57.905975  14.180435   9.404797
# 2010-01-07    6.410790  18.797266   57.947491  14.479868   9.380708
# 2010-01-08    6.453413  18.449356   58.355816  14.677710   9.348579
# ...                ...        ...         ...        ...        ...
# 2022-12-19  132.369995  62.840000  122.129997  63.540001  98.300003
# 2022-12-20  132.300003  62.790001  120.809998  63.110001  98.000000
# 2022-12-21  135.449997  63.799999  123.459999  64.239998  98.669998
# 2022-12-22  132.229996  63.340000  121.589996  63.450001  97.760002
# 2022-12-23  131.860001  63.820000  120.139999  64.410004  98.269997
#
#                    VZ        AAPL         KO         MMM          O  ...  \
# ...

# %%
stocks.swaplevel(axis = 1).sort_index(axis = 1) #index level swap and sort them from A to Z
# Out:
#                   AAPL                                                  \
#              Adj Close       Close        High         Low        Open
# Date
# 2010-01-04    6.515213    7.643214    7.660714    7.585000    7.622500
# 2010-01-05    6.526477    7.656429    7.699643    7.616071    7.664286
# 2010-01-06    6.422664    7.534643    7.686786    7.526786    7.656429
# 2010-01-07    6.410790    7.520714    7.571429    7.466071    7.562500
# 2010-01-08    6.453413    7.570714    7.571429    7.466429    7.510714
# ...                ...         ...         ...         ...         ...
# 2022-12-19  132.369995  132.369995  135.199997  131.320007  135.110001
# 2022-12-20  132.300003  132.300003  133.250000  129.889999  131.389999
# 2022-12-21  135.449997  135.449997  136.809998  132.750000  132.979996
# 2022-12-22  132.229996  132.229996  134.559998  130.300003  134.350006
# 2022-12-23  131.860001  131.860001  132.419998  129.639999  130.919998
#
# ...

# %% [markdown]
# ### Initial Inspection and Visualization

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()
# Out:
#            Adj Close                                                        \
#                 AAPL         KO        MMM          O      SBUX         VZ
# Date
# 2010-01-04  6.515213  19.081617  57.456108  13.955854  9.256215  16.828812
# 2010-01-05  6.526477  18.850788  57.096233  14.191124  9.473064  16.859154
# 2010-01-06  6.422664  18.844101  57.905975  14.180435  9.404797  16.374384
# 2010-01-07  6.410790  18.797266  57.947491  14.479868  9.380708  16.276928
# 2010-01-08  6.453413  18.449356  58.355816  14.677710  9.348579  16.287186
#
#                Close                                   ...       Open  \
#                 AAPL         KO        MMM          O  ...        MMM
# Date                                                   ...
# 2010-01-04  7.643214  28.520000  83.019997  25.290697  ...  83.089996
# 2010-01-05  7.656429  28.174999  82.500000  25.717054  ...  82.800003
# 2010-01-06  7.534643  28.165001  83.669998  25.697674  ...  83.879997
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                                               \
#                   AAPL         KO         MMM          O       SBUX
# Date
# 2022-12-19  132.369995  62.840000  122.129997  63.540001  98.300003
# 2022-12-20  132.300003  62.790001  120.809998  63.110001  98.000000
# 2022-12-21  135.449997  63.799999  123.459999  64.239998  98.669998
# 2022-12-22  132.229996  63.340000  121.589996  63.450001  97.760002
# 2022-12-23  131.860001  63.820000  120.139999  64.410004  98.269997
#
#                             Close                                    ...  \
#                    VZ        AAPL         KO         MMM          O  ...
# Date                                                                 ...
# 2022-12-19  37.029999  132.369995  62.840000  122.129997  63.540001  ...
# 2022-12-20  36.990002  132.300003  62.790001  120.809998  63.110001  ...
# 2022-12-21  37.779999  135.449997  63.799999  123.459999  64.239998  ...
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3268 entries, 2010-01-04 to 2022-12-23
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3268 non-null   float64
#  1   (Adj Close, KO)    3268 non-null   float64
#  2   (Adj Close, MMM)   3268 non-null   float64
#  3   (Adj Close, O)     3268 non-null   float64
#  4   (Adj Close, SBUX)  3268 non-null   float64
#  5   (Adj Close, VZ)    3268 non-null   float64
#  6   (Close, AAPL)      3268 non-null   float64
#  7   (Close, KO)        3268 non-null   float64
#  8   (Close, MMM)       3268 non-null   float64
#  9   (Close, O)         3268 non-null   float64
#  10  (Close, SBUX)      3268 non-null   float64
#  11  (Close, VZ)        3268 non-null   float64
#  12  (High, AAPL)       3268 non-null   float64
#  13  (High, KO)         3268 non-null   float64
#  14  (High, MMM)        3268 non-null   float64
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL           KO          MMM            O         SBUX
# count  3268.000000  3268.000000  3268.000000  3268.000000  3268.000000
# mean     49.372495    36.718213   124.184966    40.491264    50.598859
# std      47.772327    11.500511    43.699113    16.221862    29.100993
# min       5.846674    16.890404    51.292984    13.716178     8.714093
# 25%      16.623650    28.422528    79.546844    25.813262    24.632377
# 50%      27.371183    34.616791   129.678215    41.335348    49.345327
# 75%      54.801884    43.994424   159.352264    54.239970    72.472403
# max     180.959747    64.799698   218.490906    73.573242   122.130882
#
#                           Close                                         ...  \
#                 VZ         AAPL           KO          MMM            O  ...
# count  3268.000000  3268.000000  3268.000000  3268.000000  3268.000000  ...
# ...

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()
# Out:
#                 AAPL         KO        MMM          O    SBUX         VZ
# Date
# 2010-01-04  7.643214  28.520000  83.019997  25.290697  11.525  31.212946
# 2010-01-05  7.656429  28.174999  82.500000  25.717054  11.795  31.269218
# 2010-01-06  7.534643  28.165001  83.669998  25.697674  11.710  29.937416
# 2010-01-07  7.520714  28.094999  83.730003  26.240311  11.680  29.759218
# 2010-01-08  7.570714  27.575001  84.320000  26.598837  11.640  29.777975

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
#                 AAPL         KO        MMM          O    SBUX         VZ
# Date
# 2010-01-04  7.643214  28.520000  83.019997  25.290697  11.525  31.212946
# 2010-01-05  7.656429  28.174999  82.500000  25.717054  11.795  31.269218
# 2010-01-06  7.534643  28.165001  83.669998  25.697674  11.710  29.937416
# 2010-01-07  7.520714  28.094999  83.730003  26.240311  11.680  29.759218
# 2010-01-08  7.570714  27.575001  84.320000  26.598837  11.640  29.777975

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0])
#normalization from the base value
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2022-12-19    17.318629
# 2022-12-20    17.309472
# 2022-12-21    17.721602
# 2022-12-22    17.300313
# 2022-12-23    17.251904
# Name: AAPL, Length: 3268, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
#normalized value X 100
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2022-12-19    1731.862947
# 2022-12-20    1730.947206
# 2022-12-21    1772.160153
# 2022-12-22    1730.031265
# 2022-12-23    1725.190433
# Name: AAPL, Length: 3268, dtype: float64

# %%
close.iloc[0]
#base values
# Out:
# AAPL     7.643214
# KO      28.520000
# MMM     83.019997
# O       25.290697
# SBUX    11.525000
# VZ      31.212946
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
#relative close value of each day compared to the base value
# Out:
#                    AAPL          KO         MMM           O        SBUX  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318   99.373649  101.685826  102.342737
# 2010-01-06    98.579511   98.755261  100.782946  101.609195  101.605210
# 2010-01-07    98.397266   98.509814  100.855224  103.754794  101.344908
# 2010-01-08    99.051443   96.686537  101.565891  105.172415  100.997837
# ...                 ...         ...         ...         ...         ...
# 2022-12-19  1731.862947  220.336603  147.109133  251.238630  852.928471
# 2022-12-20  1730.947206  220.161290  145.519155  249.538399  850.325408
# 2022-12-21  1772.160153  223.702659  148.711159  254.006434  856.138841
# 2022-12-22  1730.031265  222.089759  146.458686  250.882767  848.242997
# 2022-12-23  1725.190433  223.772786  144.712123  254.678641  852.668112
#
#                     VZ
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.180286
# ...

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                    AAPL          KO         MMM           O        SBUX  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318   99.373649  101.685826  102.342737
# 2010-01-06    98.579511   98.755261  100.782946  101.609195  101.605210
# 2010-01-07    98.397266   98.509814  100.855224  103.754794  101.344908
# 2010-01-08    99.051443   96.686537  101.565891  105.172415  100.997837
# ...                 ...         ...         ...         ...         ...
# 2022-12-19  1731.862947  220.336603  147.109133  251.238630  852.928471
# 2022-12-20  1730.947206  220.161290  145.519155  249.538399  850.325408
# 2022-12-21  1772.160153  223.702659  148.711159  254.006434  856.138841
# 2022-12-22  1730.031265  222.089759  146.458686  250.882767  848.242997
# 2022-12-23  1725.190433  223.772786  144.712123  254.678641  852.668112
#
#                     VZ
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.180286
# ...

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### The methods diff() and pct_change()

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.AAPL.diff(periods = 1) 
#shift aapl value down to its first-next row (periods = 1) & diff between aapl and AAPL
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2022-12-19   -2.139999
# 2022-12-20   -0.069992
# 2022-12-21    3.149994
# 2022-12-22   -3.220001
# 2022-12-23   -0.369995
# Name: AAPL, Length: 3268, dtype: float64

# %%
aapl.AAPL.diff(periods = 2) 
#shift aapl value down to its second-next row (periods = 2) & diff between aapl and AAPL
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05         NaN
# 2010-01-06   -0.108571
# 2010-01-07   -0.135715
# 2010-01-08    0.036071
#                 ...
# 2022-12-19   -4.130005
# 2022-12-20   -2.209991
# 2022-12-21    3.080002
# 2022-12-22   -0.070007
# 2022-12-23   -3.589996
# Name: AAPL, Length: 3268, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)
# Out:
#                 AAPL      Diff
# Date
# 2010-01-04  7.643214       NaN
# 2010-01-05  7.656429  0.013215
# 2010-01-06  7.534643 -0.121786
# 2010-01-07  7.520714 -0.013929
# 2010-01-08  7.570714  0.050000
# 2010-01-11  7.503929 -0.066785
# 2010-01-12  7.418571 -0.085358
# 2010-01-13  7.523214  0.104643
# 2010-01-14  7.479643 -0.043571
# 2010-01-15  7.354643 -0.125000

# %%
aapl["pct_change"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      Diff  pct_change
# Date
# 2010-01-04  7.643214       NaN         NaN
# 2010-01-05  7.656429  0.013215    0.172893
# 2010-01-06  7.534643 -0.121786   -1.590632
# 2010-01-07  7.520714 -0.013929   -0.184871
# 2010-01-08  7.570714  0.050000    0.664833

# %%
aapl.AAPL.resample("BM").last()
#values in the last business day of each month
# Out:
# Date
# 2010-01-29      6.859286
# 2010-02-26      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2022-08-31    157.220001
# 2022-09-30    138.199997
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-30    131.860001
# Freq: BM, Name: AAPL, Length: 156, dtype: float64

# %% [markdown]
# ### Measuring Stock Perfromance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.pct_change().dropna()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2022-12-19 -0.015910
# 2022-12-20 -0.000529
# 2022-12-21  0.023809
# 2022-12-22 -0.023773
# 2022-12-23 -0.002798
#
# [3267 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna() #return
ret.head()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3267 entries, 2010-01-05 to 2022-12-23
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3267 non-null   float64
# dtypes: float64(1)
# memory usage: 51.0 KB

# %%
ret.plot(kind = "hist", figsize = (12 ,8), bins = 100)
plt.show()

# %%
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.001036
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000327
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    0.018094
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.018094
# dtype: float64

# %%
ann_mean_Return = ret.mean() * 252
ann_mean_Return
# Out:
# AAPL    0.261043
# dtype: float64

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns
# Out:
# AAPL    0.0825
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns
# Out:
# AAPL    0.287228
# dtype: float64

# %%
ret.std() * np.sqrt(252) #same
# Out:
# AAPL    0.287228
# dtype: float64

# %% [markdown]
# ### Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm #normalized dataset
# Out:
#                    AAPL          KO         MMM           O        SBUX  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318   99.373649  101.685826  102.342737
# 2010-01-06    98.579511   98.755261  100.782946  101.609195  101.605210
# 2010-01-07    98.397266   98.509814  100.855224  103.754794  101.344908
# 2010-01-08    99.051443   96.686537  101.565891  105.172415  100.997837
# ...                 ...         ...         ...         ...         ...
# 2022-12-19  1731.862947  220.336603  147.109133  251.238630  852.928471
# 2022-12-20  1730.947206  220.161290  145.519155  249.538399  850.325408
# 2022-12-21  1772.160153  223.702659  148.711159  254.006434  856.138841
# 2022-12-22  1730.031265  222.089759  146.458686  250.882767  848.242997
# 2022-12-23  1725.190433  223.772786  144.712123  254.678641  852.668112
#
#                     VZ
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.180286
# ...

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
#                 AAPL         KO        MMM          O    SBUX         VZ
# Date
# 2010-01-04  7.643214  28.520000  83.019997  25.290697  11.525  31.212946
# 2010-01-05  7.656429  28.174999  82.500000  25.717054  11.795  31.269218
# 2010-01-06  7.534643  28.165001  83.669998  25.697674  11.710  29.937416
# 2010-01-07  7.520714  28.094999  83.730003  26.240311  11.680  29.759218
# 2010-01-08  7.570714  27.575001  84.320000  26.598837  11.640  29.777975

# %%
close.pct_change().dropna()
# Out:
#                 AAPL        KO       MMM         O      SBUX        VZ
# Date
# 2010-01-05  0.001729 -0.012097 -0.006264  0.016858  0.023427  0.001803
# 2010-01-06 -0.015906 -0.000355  0.014182 -0.000754 -0.007206 -0.042591
# 2010-01-07 -0.001849 -0.002485  0.000717  0.021116 -0.002562 -0.005952
# 2010-01-08  0.006648 -0.018509  0.007046  0.013663 -0.003425  0.000630
# 2010-01-11 -0.008821  0.020308 -0.004032 -0.007650 -0.003007  0.004094
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-19 -0.015910  0.001434  0.003616  0.000945 -0.005363 -0.002425
# 2022-12-20 -0.000529 -0.000796 -0.010808 -0.006767 -0.003052 -0.001080
# 2022-12-21  0.023809  0.016085  0.021935  0.017905  0.006837  0.021357
# 2022-12-22 -0.023773 -0.007210 -0.015147 -0.012298 -0.009223  0.014029
# 2022-12-23 -0.002798  0.007578 -0.011925  0.015130  0.005217  0.002610
#
# [3267 rows x 6 columns]

# %%
ret = close.pct_change().dropna() #return

# %%
ret.head()
# Out:
#                 AAPL        KO       MMM         O      SBUX        VZ
# Date
# 2010-01-05  0.001729 -0.012097 -0.006264  0.016858  0.023427  0.001803
# 2010-01-06 -0.015906 -0.000355  0.014182 -0.000754 -0.007206 -0.042591
# 2010-01-07 -0.001849 -0.002485  0.000717  0.021116 -0.002562 -0.005952
# 2010-01-08  0.006648 -0.018509  0.007046  0.013663 -0.003425  0.000630
# 2010-01-11 -0.008821  0.020308 -0.004032 -0.007650 -0.003007  0.004094

# %%
ret.describe()
# Out:
#               AAPL           KO          MMM            O         SBUX  \
# count  3267.000000  3267.000000  3267.000000  3267.000000  3267.000000
# mean      0.001036     0.000308     0.000209     0.000415     0.000801
# std       0.018094     0.011101     0.013845     0.015900     0.017002
# min      -0.128647    -0.096725    -0.129450    -0.249305    -0.162042
# 25%      -0.007636    -0.004740    -0.005707    -0.006804    -0.007335
# 50%       0.000865     0.000488     0.000563     0.001034     0.000714
# 75%       0.010640     0.005890     0.007167     0.008065     0.008860
# max       0.119808     0.064796     0.125986     0.169128     0.147303
#
#                 VZ
# count  3267.000000
# mean      0.000128
# std       0.011362
# min      -0.067352
# 25%      -0.006017
# 50%       0.000261
# 75%       0.006246
# max       0.076802

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  3267.0  0.001036  0.018094 -0.128647 -0.007636  0.000865  0.010640
# KO    3267.0  0.000308  0.011101 -0.096725 -0.004740  0.000488  0.005890
# MMM   3267.0  0.000209  0.013845 -0.129450 -0.005707  0.000563  0.007167
# O     3267.0  0.000415  0.015900 -0.249305 -0.006804  0.001034  0.008065
# SBUX  3267.0  0.000801  0.017002 -0.162042 -0.007335  0.000714  0.008860
# VZ    3267.0  0.000128  0.011362 -0.067352 -0.006017  0.000261  0.006246
#
#            max
# AAPL  0.119808
# KO    0.064796
# MMM   0.125986
# O     0.169128
# SBUX  0.147303
# VZ    0.076802

# %%
ret.describe().T.loc[:, ["mean", "std"]] 
#mean for averaged daily return
#std for averaged daily volatility (risk)
# Out:
#           mean       std
# AAPL  0.001036  0.018094
# KO    0.000308  0.011101
# MMM   0.000209  0.013845
# O     0.000415  0.015900
# SBUX  0.000801  0.017002
# VZ    0.000128  0.011362

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001036  0.018094
# KO    0.000308  0.011101
# MMM   0.000209  0.013845
# O     0.000415  0.015900
# SBUX  0.000801  0.017002
# VZ    0.000128  0.011362

# %%
np.sqrt(252)
# Out:
# 15.874507866387544

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252) 
#auunalize: converting daily returns/volatilities to annual returns/volatilities

# %% [markdown]
# - Volatility, or standard deviation, is the square root of variance.
# - Volatility is standard deviation of returns, which is the square root of variance.
# - Standard deviation is the square root of variance and therefore it is proportional to the square root of time.
# - Volatility is standard deviation and therefore it is proportional to the square root of time.
# - See: https://charon.me/posts/quant_trade/calculation/

# %%
summary #annualized average return and volatility of each stock between 2010 and 2022
# Out:
#           mean       std
# AAPL  0.261043  0.287228
# KO    0.077736  0.176215
# MMM   0.052794  0.219783
# O     0.104698  0.252401
# SBUX  0.201760  0.269893
# VZ    0.032272  0.180367

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
plt.show()

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ### Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
#                 AAPL        KO       MMM         O      SBUX        VZ
# Date
# 2010-01-05  0.001729 -0.012097 -0.006264  0.016858  0.023427  0.001803
# 2010-01-06 -0.015906 -0.000355  0.014182 -0.000754 -0.007206 -0.042591
# 2010-01-07 -0.001849 -0.002485  0.000717  0.021116 -0.002562 -0.005952
# 2010-01-08  0.006648 -0.018509  0.007046  0.013663 -0.003425  0.000630
# 2010-01-11 -0.008821  0.020308 -0.004032 -0.007650 -0.003007  0.004094

# %%
ret.cov()
# Out:
#           AAPL        KO       MMM         O      SBUX        VZ
# AAPL  0.000327  0.000071  0.000108  0.000090  0.000140  0.000055
# KO    0.000071  0.000123  0.000078  0.000082  0.000082  0.000060
# MMM   0.000108  0.000078  0.000192  0.000089  0.000107  0.000064
# O     0.000090  0.000082  0.000089  0.000253  0.000121  0.000067
# SBUX  0.000140  0.000082  0.000107  0.000121  0.000289  0.000061
# VZ    0.000055  0.000060  0.000064  0.000067  0.000061  0.000129

# %%
ret.corr()
# Out:
#           AAPL        KO       MMM         O      SBUX        VZ
# AAPL  1.000000  0.352315  0.431843  0.311828  0.454517  0.267205
# KO    0.352315  1.000000  0.504565  0.466921  0.432649  0.473880
# MMM   0.431843  0.504565  1.000000  0.403547  0.454869  0.408443
# O     0.311828  0.466921  0.403547  1.000000  0.447384  0.371871
# SBUX  0.454517  0.432649  0.454869  0.447384  1.000000  0.314944
# VZ    0.267205  0.473880  0.408443  0.371871  0.314944  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()
