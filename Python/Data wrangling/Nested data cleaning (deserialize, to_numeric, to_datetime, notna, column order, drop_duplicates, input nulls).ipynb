# %% [markdown]
# # Data Cleaning - Tidy up messy Datasets (Movies Dataset)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("movies_metadata.csv", low_memory=False)
df
# nested json data in some columns
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# - __Load__ and __inspect__ the __df__. __Identify__ columns with nested / stringified json data.

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.genres[0]
# nested- stringified json data.
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df.info()
# some mixed or false data types
# many missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# ## Dropping irrelevant Columns

# %% [markdown]
# - __Drop__ the irrelevant columns 'adult', 'imdb_id', 'original_title', 'video' and 'homepage'.

# %%
df.adult.value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
df.drop(columns = ['adult', 'imdb_id', 'original_title', 'homepage'], axis=1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4494 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   45463 non-null  object
#  9   production_countries   45463 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       45460 non-null  object
# ...

# %% [markdown]
# ## How to handle stringified JSON columns and deserialize

# %% [markdown]
# - __Evaluate__ Python Expressions in the stringified columns ["genres", "production_countries", "production_companies", "spoken_languages"]. <br> __Deserialize__ if necessary.

# %%
import json
import ast

# %%
df.genres[0]
# json data that contains a dictionary of keys-values pairs
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df.genres.apply(ast.literal_eval)[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df.genres = df.genres.apply(ast.literal_eval)

# %%
import numpy as np

# %%
df.belongs_to_collection
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
df.belongs_to_collection[1]
# Out:
# nan

# %%
df.belongs_to_collection.apply(lambda x: isinstance(x, str))
# whether the element contains string or not?
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45466, dtype: bool

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)
# if it's true (yes strings), perform ast.literal_eval(x), i.e., deserialize (convert string into object)
# if not (no strings), impute np.nan

# %%
df.belongs_to_collection
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection[0]
# deserialized (only with 'True' strings)
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
df.belongs_to_collection[1]
# Out:
# nan

# %%
df.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
df.spoken_languages[1]
# Out:
# "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]"

# %%
df.spoken_languages = df.spoken_languages.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.spoken_languages[1]
# deserialized (only with 'True' strings)
# Out:
# [{'iso_639_1': 'en', 'name': 'English'},
#  {'iso_639_1': 'fr', 'name': 'Français'}]

# %%
df.production_countries[22]
# Out:
# "[{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]"

# %%
df.production_countries = df.production_countries.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.production_countries[22]
# Out:
# [{'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
df.production_companies[22]
# Out:
# "[{'name': 'Silver Pictures', 'id': 1885}, {'name': 'Canal+', 'id': 5358}, {'name': 'Warner Bros.', 'id': 6194}, {'name': 'Dino De Laurentiis Company', 'id': 10308}, {'name': 'Donner/Shuler-Donner Productions', 'id': 23397}, {'name': 'Evansgideon/Lazar', 'id': 25061}]"

# %%
df.production_companies = df.production_companies.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.production_companies[22]
# Out:
# [{'name': 'Silver Pictures', 'id': 1885},
#  {'name': 'Canal+', 'id': 5358},
#  {'name': 'Warner Bros.', 'id': 6194},
#  {'name': 'Dino De Laurentiis Company', 'id': 10308},
#  {'name': 'Donner/Shuler-Donner Productions', 'id': 23397},
#  {'name': 'Evansgideon/Lazar', 'id': 25061}]

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# ## How to flatten nested Columns

# %% [markdown]
# - __Extract__ only the __collection name__ from the column "belongs_to_collection" and __overwrite__ "belongs_to_collection". <br> For example: The value in the first row (Toy Story) should be 'Toy Story Collection'.

# %%
df.belongs_to_collection[0]
# it's dictionary format (dict)
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
df.belongs_to_collection.apply(lambda x: x['name'] if isinstance(x, dict) else np.nan)
# if it's true (yes dict), extract 'name' from x,
# if not (no dict), impute np.nan
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 45461                               NaN
# 45462                               NaN
# 45463                               NaN
# 45464                               NaN
# 45465                               NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x: x['name'] if isinstance(x, dict) else np.nan)

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 45461                               NaN
# 45462                               NaN
# 45463                               NaN
# 45464                               NaN
# 45465                               NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection.value_counts(dropna = False).head(20)
# Out:
# NaN                                       40975
# The Bowery Boys                              29
# Totò Collection                              27
# James Bond Collection                        26
# Zatôichi: The Blind Swordsman                26
# The Carry On Collection                      25
# Pokémon Collection                           22
# Charlie Chan (Sidney Toler) Collection       21
# Godzilla (Showa) Collection                  16
# Uuno Turhapuro                               15
# Dragon Ball Z (Movie) Collection             15
# Charlie Chan (Warner Oland) Collection       15
# The Land Before Time Collection              14
# Monster High Collection                      14
# Sharpe Collection                            13
# George Carlin Comedy Collection              13
# Johan Falk GSI Collection                    12
# Sherlock Holmes (1939 series)                12
# Friday the 13th Collection                   12
# The Amityville Horror Collection             12
# ...

# %% [markdown]
# - __Extract__ all __genre names__ from the column "genres" and __overwrite__ "genres". If a movie has more than one genre, __seperate genres by a pipe__ "|".

# %%
df.genres[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df.genres[45464]
# empty list
# Out:
# []

# %%
df.genres.apply(lambda x: "|".join(i['name'] for i in x))
# join "|" for every and each i where i is name in x.
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 45461                Drama|Family
# 45462                       Drama
# 45463       Action|Drama|Thriller
# 45464
# 45465
# Name: genres, Length: 45466, dtype: object

# %%
df.genres = df.genres.apply(lambda x: "|".join(i['name'] for i in x))

# %%
df.genres.value_counts(dropna = False).head(20)
# 2442 = empty lists or empty strings
# Out:
# Drama                   5000
# Comedy                  3621
# Documentary             2723
#                         2442
# Drama|Romance           1301
# Comedy|Drama            1135
# Horror                   974
# Comedy|Romance           930
# Comedy|Drama|Romance     593
# Drama|Comedy             532
# Horror|Thriller          528
# Drama|Thriller           497
# Thriller                 465
# Crime|Drama              430
# Romance|Drama            343
# Western                  318
# Action|Thriller          301
# Drama|Foreign            283
# Action                   278
# Drama|History            267
# Name: genres, dtype: int64

# %%
df.genres.replace("", np.nan, inplace = True)

# %%
df.genres.value_counts(dropna = False).head(20)
# 2442 = NaN
# Out:
# Drama                   5000
# Comedy                  3621
# Documentary             2723
# NaN                     2442
# Drama|Romance           1301
# Comedy|Drama            1135
# Horror                   974
# Comedy|Romance           930
# Comedy|Drama|Romance     593
# Drama|Comedy             532
# Horror|Thriller          528
# Drama|Thriller           497
# Thriller                 465
# Crime|Drama              430
# Romance|Drama            343
# Western                  318
# Action|Thriller          301
# Drama|Foreign            283
# Action                   278
# Drama|History            267
# Name: genres, dtype: int64

# %% [markdown]
# - __Extract__ all __spoken language names__ from the column "spoken_languages" and __overwrite__ "spoken_languages". If a movie has more than one spoken language, __seperate spoken languages by a pipe__ "|".

# %%
df.spoken_languages[22]
# Out:
# [{'iso_639_1': 'en', 'name': 'English'},
#  {'iso_639_1': 'es', 'name': 'Español'},
#  {'iso_639_1': 'nl', 'name': 'Nederlands'}]

# %%
df.spoken_languages[45464]
# empty list
# Out:
# []

# %%
# df.spoken_languages.apply(lambda x: "|".join(i['name'] for i in x))
# 'float' object is not iterable

# %%
df.spoken_languages.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)
# if x is true (yes list, i.e. no empty list), join "|" for every and each i where i is name in x. 
# if not (empty list), impute np.nan
# Out:
# 0                 English
# 1        English|Français
# 2                 English
# 3                 English
# 4                 English
#                ...
# 45461               فارسی
# 45462
# 45463             English
# 45464
# 45465             English
# Name: spoken_languages, Length: 45466, dtype: object

# %%
df.spoken_languages = df.spoken_languages.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.spoken_languages[22]
# Out:
# 'English|Español|Nederlands'

# %%
df.spoken_languages[45464]
# Out:
# ''

# %%
df.spoken_languages.value_counts(dropna = False).head(20)
# 3952 = empty lists or empty strings
# Out:
# English             22395
#                      3952
# Français             1853
# 日本語                  1289
# Italiano             1218
# Español               902
# Pусский               807
# Deutsch               762
# English|Français      681
# English|Español       572
# हिन्दी                481
# English|Deutsch       462
# 한국어/조선말               425
# 普通话                   347
# English|Italiano      326
# svenska               311
# No Language           303
# suomi                 275
# Português             275
# Polski                213
# Name: spoken_languages, dtype: int64

# %%
df.spoken_languages.replace("", np.nan, inplace = True)

# %%
df.spoken_languages.value_counts(dropna = False).head(20)
# 3958 = NaN
# Out:
# English             22395
# NaN                  3958
# Français             1853
# 日本語                  1289
# Italiano             1218
# Español               902
# Pусский               807
# Deutsch               762
# English|Français      681
# English|Español       572
# हिन्दी                481
# English|Deutsch       462
# 한국어/조선말               425
# 普通话                   347
# English|Italiano      326
# svenska               311
# No Language           303
# Português             275
# suomi                 275
# Polski                213
# Name: spoken_languages, dtype: int64

# %% [markdown]
# - __Extract__ all __production countries names__ from the column "production_countries" and __overwrite__ "production_countries". If a movie has more than one production country, __seperate production countries by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'United States of America'.

# %%
df.production_countries[22]
# Out:
# [{'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
# df.production_countries.apply(lambda x: "|".join(i['name'] for i in x))
# 'float' object is not iterable

# %%
df.production_countries.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)
# if x is true (yes list, i.e. no empty list), join "|" for every and each i where i is name in x. 
# if not (empty list), impute np.nan
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
#                    ...
# 45461                        Iran
# 45462                 Philippines
# 45463    United States of America
# 45464                      Russia
# 45465              United Kingdom
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_countries = df.production_countries.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.production_countries[22]
# Out:
# 'France|United States of America'

# %%
df.production_countries.replace("", np.nan, inplace = True)

# %%
df.production_countries.value_counts(dropna = False).head(20)
# 6288 = NaN
# Out:
# United States of America                   17851
# NaN                                         6288
# United Kingdom                              2238
# France                                      1654
# Japan                                       1356
# Italy                                       1030
# Canada                                       840
# Germany                                      749
# India                                        735
# Russia                                       735
# United Kingdom|United States of America      569
# South Korea                                  432
# Spain                                        398
# Hong Kong                                    365
# Canada|United States of America              365
# Australia                                    336
# Sweden                                       332
# Finland                                      271
# France|Italy                                 235
# ...

# %% [markdown]
# - __Extract__ all __production companies names__ from the column "production_companies" and __overwrite__ "production_companies". If a movie has more than one production company, __seperate production companies by a pipe__ "|".

# %%
df.production_companies[22]
# Out:
# [{'name': 'Silver Pictures', 'id': 1885},
#  {'name': 'Canal+', 'id': 5358},
#  {'name': 'Warner Bros.', 'id': 6194},
#  {'name': 'Dino De Laurentiis Company', 'id': 10308},
#  {'name': 'Donner/Shuler-Donner Productions', 'id': 23397},
#  {'name': 'Evansgideon/Lazar', 'id': 25061}]

# %%
# df.production_companies.apply(lambda x: "|".join(i['name'] for i in x))
# 'float' object is not iterable

# %%
df.production_companies = df.production_companies.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)
df.production_companies
# if x is true (yes list, i.e. no empty list), join "|" for every and each i where i is name in x. 
# if not (empty list), impute np.nan
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 45461
# 45462                                          Sine Olivia
# 45463                              American World Pictures
# 45464                                            Yermoliev
# 45465
# Name: production_companies, Length: 45466, dtype: object

# %%
df.production_companies.replace("", np.nan, inplace = True)

# %%
df.production_companies.value_counts(dropna = False).head(20)
# 11881 = NaN
# Out:
# NaN                                       11881
# Metro-Goldwyn-Mayer (MGM)                   742
# Warner Bros.                                540
# Paramount Pictures                          505
# Twentieth Century Fox Film Corporation      439
# Universal Pictures                          320
# RKO Radio Pictures                          247
# Columbia Pictures Corporation               207
# Columbia Pictures                           146
# Mosfilm                                     145
# Walt Disney Pictures                         85
# Universal International Pictures (UI)        82
# Walt Disney Productions                      75
# New Line Cinema                              75
# Shaw Brothers                                71
# Touchstone Pictures                          70
# Toho Company                                 65
# TriStar Pictures                             62
# Orion Pictures                               61
# Hammer Film Productions                      60
# ...

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40975
# budget                       0
# genres                    2442
# id                           0
# original_language           11
# overview                   954
# popularity                   5
# poster_path                386
# production_companies     11881
# production_countries      6288
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages          3958
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
pd.read_csv("movies_metadata.csv", low_memory=False).isna().sum()
# compare
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# ## Cleaning Numerical Columns

# %% [markdown]
# - __Convert__ the datatype in the columns __"budget"__, __"id"__ and __"popularity"__ __to numeric__. Set invalid values as NaN.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
# df.budget.astype("float64")
# could not convert string to float

# %%
pd.to_numeric(df.budget, errors = "coerce")
# If 'coerce', then invalid parsing will be set as NaN.
# Out:
# 0       30000000.00
# 1       65000000.00
# 2              0.00
# 3       16000000.00
# 4              0.00
#             ...
# 45461          0.00
# 45462          0.00
# 45463          0.00
# 45464          0.00
# 45465          0.00
# Name: budget, Length: 45466, dtype: float64

# %%
df.budget = pd.to_numeric(df.budget, errors = "coerce")
# If 'coerce', then invalid parsing will be set as NaN.

# %%
df.revenue = pd.to_numeric(df.revenue, errors = "coerce")
# If 'coerce', then invalid parsing will be set as NaN.

# %%
df.popularity = pd.to_numeric(df.popularity, errors = "coerce")
# If 'coerce', then invalid parsing will be set as NaN.

# %%
df.id = pd.to_numeric(df.id, errors = "coerce")
# If 'coerce', then invalid parsing will be set as NaN.

# %% [markdown]
# - __Analyze__ the columns __"budget"__ and __"revenue"__ and __"runtime"__. Analyze movies with a budget/revenue/runtime of 0. Do you think the value 0 is the most appropriate value?

# %%
df.budget.value_counts(dropna = False)
# 0.00 values may mean place holders for missing values
# whenever people do not know the value, they simply type in 0 for the budget.
# Out:
# 0.00           36573
# 5000000.00       286
# 10000000.00      259
# 20000000.00      243
# 2000000.00       242
#                ...
# 9750000.00         1
# 7275000.00         1
# 78146652.00        1
# 280.00             1
# 1254040.00         1
# Name: budget, Length: 1224, dtype: int64

# %%
df.budget = df.budget.replace(0, np.nan)

# %%
df.revenue.value_counts(dropna = False)
# 0.00 values may mean place holders for missing values
# whenever people do not know the value, they simply type in 0 for the revenue.
# Out:
# 0.00           38052
# 12000000.00       20
# 10000000.00       19
# 11000000.00       19
# 2000000.00        18
#                ...
# 36565280.00        1
# 439564.00          1
# 35610100.00        1
# 10217873.00        1
# 1413000.00         1
# Name: revenue, Length: 6864, dtype: int64

# %%
df.revenue = df.revenue.replace(0, np.nan)

# %%
df.runtime.value_counts(dropna = False)
# 0.00 values may mean place holders for missing values
# whenever people do not know the value, they simply type in 0 for the runtime.
# Out:
# 90.00     2556
# 0.00      1558
# 100.00    1470
# 95.00     1412
# 93.00     1214
#           ...
# 410.00       1
# 283.00       1
# 238.00       1
# 566.00       1
# 780.00       1
# Name: runtime, Length: 354, dtype: int64

# %%
df.runtime = df.runtime.replace(0, np.nan)

# %% [markdown]
# - The columns "budget" and "revenue" shall show values in Million USD. __Convert and Overwrite__!

# %%
df.budget = df.budget.div(1000000)

# %%
df.revenue = df.revenue.div(1000000)

# %%
df.rename(columns = {"revenue":"revenue_musd", "budget":"budget_musd"}, inplace = True)

# %% [markdown]
# - __Analyze__ movies with a vote_count of 0. What´s the vote_average for those movies? Do you think this value is the most appropriate value?

# %%
df.vote_count.value_counts()
# 0.00 2899 times
# Out:
# 1.00       3264
# 2.00       3132
# 0.00       2899
# 3.00       2787
# 4.00       2480
#            ...
# 2755.00       1
# 1187.00       1
# 4200.00       1
# 3322.00       1
# 2712.00       1
# Name: vote_count, Length: 1820, dtype: int64

# %%
df.vote_average.value_counts(dropna = False).head(20)
# Out:
# 0.00    2998
# 6.00    2468
# 5.00    2001
# 7.00    1886
# 6.50    1722
# 6.30    1603
# 5.50    1381
# 5.80    1369
# 6.40    1350
# 6.70    1342
# 6.80    1324
# 6.10    1281
# 6.60    1263
# 6.20    1253
# 5.90    1196
# 5.30    1082
# 5.70    1046
# 6.90    1037
# 5.60    1006
# 7.30    1000
# Name: vote_average, dtype: int64

# %%
df.loc[df.vote_count == 0, "vote_average"]
# Those with 0 vote_count (i.e., no values) have 0 vote_average - this is not meaningful.
# Out:
# 83      0.00
# 107     0.00
# 126     0.00
# 132     0.00
# 137     0.00
#         ...
# 45432   0.00
# 45434   0.00
# 45452   0.00
# 45464   0.00
# 45465   0.00
# Name: vote_average, Length: 2899, dtype: float64

# %%
df.loc[df.vote_count == 0, "vote_average"] = np.nan
# We input nulls to vote_average for the movies with 0 vote_count values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45460 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %% [markdown]
# ## Cleaning DateTime Columns

# %% [markdown]
# - __Convert__ the datatype in the column __"release_date"__ __to datetime__. Set invalid values as NaN.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45460 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
df.release_date
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45461           NaN
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45466, dtype: object

# %%
df.release_date = pd.to_datetime(df.release_date, yearfirst = True, errors = "coerce")
df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45461          NaT
# 45462   2011-11-17
# 45463   2003-08-01
# 45464   1917-10-21
# 45465   2017-06-09
# Name: release_date, Length: 45466, dtype: datetime64[ns]

# %% [markdown]
# ## Cleaning Text / String Columns

# %% [markdown]
# - __Analyze__ the text columns "overview" and "tagline". Try to identify __missing data that is not represented by NaN__ (e.g. "No Data"). __Replace as NaN__ (np.nan)!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45460 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45376 non-null  datetime64[ns]
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
df.overview
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45461          Rising and falling between a man and woman.
# 45462    An artist struggles to finish his work while a...
# 45463    When one of her hits goes wrong, a professiona...
# 45464    In a small town live two brothers, one a minis...
# 45465    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45466, dtype: object

# %%
df.overview.value_counts(dropna = False).head(20)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              954
# ...

# %%
df.overview = df.overview.replace(["No overview found", "No Overview", "Released", " ","No overview yet.","No movie overview available.", "No overview found."], np.nan)

# %%
df.tagline.value_counts(dropna = False).head(40)
# Out:
# NaN                                                                                                                      25054
# Based on a true story.                                                                                                       7
# Trust no one.                                                                                                                4
# Be careful what you wish for.                                                                                                4
# -                                                                                                                            4
# Classic Albums                                                                                                               3
# Some doors should never be opened.                                                                                           3
# ...

# %%
df.tagline = df.tagline.replace(["-"], np.nan)

# %% [markdown]
# ## Removing Duplicates

# %% [markdown]
# - __Identify__ and __remove__ duplicates!

# %%
df[df.duplicated(subset = "id", keep = False)].sort_values(by = "id")
# same id, different vote_count
# same id, different popularity, etc...
# Out:
#       belongs_to_collection  budget_musd  \
# 33826                   NaN        30.00
# 5865                    NaN        30.00
# 9165                    NaN          NaN
# 7345                    NaN          NaN
# 44821    Pokémon Collection        16.00
# ...                     ...          ...
# 40040                   NaN         0.98
# 33184                   NaN         0.98
# 19730                   NaN          NaN
# 29503                   NaN          NaN
# 35587                   NaN          NaN
#
#                                                   genres        id  \
# 33826                Comedy|Crime|Drama|Romance|Thriller   4912.00
# 5865                 Comedy|Crime|Drama|Romance|Thriller   4912.00
# 9165                                Crime|Drama|Thriller   5511.00
# 7345                                Crime|Drama|Thriller   5511.00
# 44821          Adventure|Fantasy|Animation|Action|Family  10991.00
# ...

# %%
df.drop_duplicates(subset = "id", inplace = True)

# %%
df.id.value_counts(dropna = False)
# Out:
# 862.00       1
# 74458.00     1
# 296206.00    1
# 107308.00    1
# 16247.00     1
#             ..
# 44399.00     1
# 10138.00     1
# 32084.00     1
# 42191.00     1
# 461257.00    1
# Name: id, Length: 45434, dtype: int64

# %% [markdown]
# ## Handling Missing Values & Removing Observations

# %% [markdown]
# - __Drop__ all rows/movies with unknown __id__ or __title__.

# %%
df.id.sort_values(ascending = True)
# Out:
# 4342         2.00
# 12947        3.00
# 17           5.00
# 474          6.00
# 256         11.00
#            ...
# 45273   467731.00
# 21891   468343.00
# 45398   468707.00
# 20189   469172.00
# 19730         NaN
# Name: id, Length: 45434, dtype: float64

# %%
df.drop(index = [19730], inplace = True)

# %% [markdown]
# - __Keep__ only those rows/movies in the df with __10 or more non-NaN__ values.

# %%
mask1 = df.notna().sum(axis = 1) >= 10
mask1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 45461    True
# 45462    True
# 45463    True
# 45464    True
# 45465    True
# Length: 45433, dtype: bool

# %%
df  = df.loc[mask1].copy()
df
# Out:
#                 belongs_to_collection  budget_musd                    genres  \
# 0                Toy Story Collection        30.00   Animation|Comedy|Family
# 1                                 NaN        65.00  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection          NaN            Romance|Comedy
# 3                                 NaN        16.00      Comedy|Drama|Romance
# 4      Father of the Bride Collection          NaN                    Comedy
# ...                               ...          ...                       ...
# 45461                             NaN          NaN              Drama|Family
# 45462                             NaN          NaN                     Drama
# 45463                             NaN          NaN     Action|Drama|Thriller
# 45464                             NaN          NaN                       NaN
# 45465                             NaN          NaN                       NaN
#
#              id original_language  \
# ...

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40815
# budget_musd              36422
# genres                    2319
# id                           0
# original_language           11
# overview                  1052
# popularity                   0
# poster_path                293
# production_companies     11740
# production_countries      6151
# release_date                51
# revenue_musd             37904
# runtime                   1697
# spoken_languages          3826
# status                      72
# tagline                  24905
# title                        0
# video                        0
# vote_average              2778
# vote_count                   0
# dtype: int64

# %% [markdown]
# ## Final (Cleaning) Steps

# %% [markdown]
# - __Keep__ only those rows/movies in the df with __status "Released"__. Then __drop__ the column "status".

# %%
df.status.value_counts()
# Out:
# Released           44867
# Rumored              228
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %%
df.status.notna()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 45461    True
# 45462    True
# 45463    True
# 45464    True
# 45465    True
# Name: status, Length: 45302, dtype: bool

# %%
df_released = df.loc[df.status == "Released"].copy()
df_released
# Out:
#                 belongs_to_collection  budget_musd                    genres  \
# 0                Toy Story Collection        30.00   Animation|Comedy|Family
# 1                                 NaN        65.00  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection          NaN            Romance|Comedy
# 3                                 NaN        16.00      Comedy|Drama|Romance
# 4      Father of the Bride Collection          NaN                    Comedy
# ...                               ...          ...                       ...
# 45461                             NaN          NaN              Drama|Family
# 45462                             NaN          NaN                     Drama
# 45463                             NaN          NaN     Action|Drama|Thriller
# 45464                             NaN          NaN                       NaN
# 45465                             NaN          NaN                       NaN
#
#              id original_language  \
# ...

# %%
df_released = df_released.drop(columns = "status")
df_released
# Out:
#                 belongs_to_collection  budget_musd                    genres  \
# 0                Toy Story Collection        30.00   Animation|Comedy|Family
# 1                                 NaN        65.00  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection          NaN            Romance|Comedy
# 3                                 NaN        16.00      Comedy|Drama|Romance
# 4      Father of the Bride Collection          NaN                    Comedy
# ...                               ...          ...                       ...
# 45461                             NaN          NaN              Drama|Family
# 45462                             NaN          NaN                     Drama
# 45463                             NaN          NaN     Action|Drama|Thriller
# 45464                             NaN          NaN                       NaN
# 45465                             NaN          NaN                       NaN
#
#              id original_language  \
# ...

# %% [markdown]
# - The Order of the columns should be as follows:

# %%
order = ["id", "title", "tagline", "release_date", "genres", "belongs_to_collection", 
"original_language", "budget_musd", "revenue_musd", "production_companies",
"production_countries", "vote_count", "vote_average", "popularity", "runtime",
"overview", "spoken_languages", "poster_path"]

# %%
df = df_released.reindex(columns=order)
df
# Out:
#              id                        title  \
# 0        862.00                    Toy Story
# 1       8844.00                      Jumanji
# 2      15602.00             Grumpier Old Men
# 3      31357.00            Waiting to Exhale
# 4      11862.00  Father of the Bride Part II
# ...         ...                          ...
# 45461 439050.00                       Subdue
# 45462 111109.00          Century of Birthing
# 45463  67758.00                     Betrayal
# 45464 227506.00             Satan Triumphant
# 45465 461257.00                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# ...

# %% [markdown]
# - __Reset__ the Index and create a __RangeIndex__.

# %%
df.reset_index(drop = False, inplace=True)

# %% [markdown]
# - __Save__ the cleaned dataset in a __csv-file__.

# %%
df.to_csv("df.csv")
