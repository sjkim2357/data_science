# %% [markdown]
# # Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("movies_complete.csv", parse_dates = ["release_date"])
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
df.info()
# many missing values in budget_musd & revenue_musd
# parse_dates = ["release_date"] - hence, release_date in datetime64[ns]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
df.describe(include = "O")
# 44691 non-missing values in title
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
df[df.belongs_to_collection == "James Bond Collection"].head()
# Out:
#        id                  title  \
# 9     710              GoldenEye
# 1621  714    Tomorrow Never Dies
# 2240  707       A View to a Kill
# 2804  658             Goldfinger
# 2805  657  From Russia with Love
#
#                                                 tagline release_date  \
# 9                  No limits. No fears. No substitutes.   1995-11-16
# 1621  Yesterday is a memory. Today is history. Tomor...   1997-12-11
# 2240              Has James Bond finally met his match?   1985-05-24
# 2804       Everything he touches turns into excitement!   1964-09-17
# 2805  The world's masters of murder pull out all the...   1963-10-11
#
#                          genres  belongs_to_collection original_language  \
# 9     Adventure|Action|Thriller  James Bond Collection                en
# 1621  Adventure|Action|Thriller  James Bond Collection                en
# 2240  Adventure|Action|Thriller  James Bond Collection                en
# ...

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.iloc[df.revenue_musd.sort_values(ascending = False).head(5).index].title
# Out:
# 14448                          Avatar
# 26265    Star Wars: The Force Awakens
# 1620                          Titanic
# 17669                    The Avengers
# 24812                  Jurassic World
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
df.iloc[df.budget_musd.sort_values(ascending = False).head(5).index].title
# Out:
# 16986    Pirates of the Caribbean: On Stranger Tides
# 11743       Pirates of the Caribbean: At World's End
# 26268                        Avengers: Age of Ultron
# 10985                               Superman Returns
# 18517                                    John Carter
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %% [markdown]
# Highest Profit (=Revenue - Budget)

# %%
df["profit"] = df.revenue_musd.sub(df.budget_musd)
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.iloc[df.profit.sort_values(ascending = False).head(5).index].title
# Out:
# 14448                          Avatar
# 26265    Star Wars: The Force Awakens
# 1620                          Titanic
# 24812                  Jurassic World
# 28501                       Furious 7
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
df.iloc[df.profit.sort_values(ascending = True).head(5).index].title
# Out:
# 20959                                The Lone Ranger
# 7164                                       The Alamo
# 16659                                Mars Needs Moms
# 43611    Valerian and the City of a Thousand Planets
# 2684                                The 13th Warrior
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %% [markdown]
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)

# %%
df["return"] = df.revenue_musd.div(df.budget_musd)
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
highbudget = df.loc[df.budget_musd >= 10].copy()
highbudget.head()
# Out:
#       id              title  \
# 0    862          Toy Story
# 1   8844            Jumanji
# 3  31357  Waiting to Exhale
# 5    949               Heat
# 6  11860            Sabrina
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 3  Friends are the people who let you be yourself...   1995-12-22
# 5                           A Los Angeles Crime Saga   1995-12-15
# 6  You are cordially invited to the most surprisi...   1995-12-15
#
#                         genres belongs_to_collection original_language  \
# 0      Animation|Comedy|Family  Toy Story Collection                en
# 1     Adventure|Fantasy|Family                   NaN                en
# 3         Comedy|Drama|Romance                   NaN                en
# 5  Action|Crime|Drama|Thriller                   NaN                en
# ...

# %%
highbudget.sort_values(by = "return", ascending = False).head(5).title
# Out:
# 1055     E.T. the Extra-Terrestrial
# 255                       Star Wars
# 588                    Pretty Woman
# 18300              The Intouchables
# 1144        The Empire Strikes Back
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
highbudget.sort_values(by = "return", ascending = True).head(5).title
# Out:
# 6955     Chasing Liberty
# 8041         The Cookout
# 17381           Deadfall
# 6678          In the Cut
# 20015      The Samaritan
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %% [markdown]
# - Highest number of Votes

# %%
df.iloc[df.vote_count.sort_values(ascending = False).head(5).index].title
# Out:
# 15368          Inception
# 12396    The Dark Knight
# 14448             Avatar
# 17669       The Avengers
# 26272           Deadpool
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Highest Rating__
# - among those with at least 10 vote_count

# %%
highVoteCount = df.loc[df.vote_count >= 10].copy()
highVoteCount
# Out:
#            id                         title  \
# 0         862                     Toy Story
# 1        8844                       Jumanji
# 2       15602              Grumpier Old Men
# 3       31357             Waiting to Exhale
# 4       11862   Father of the Bride Part II
# ...       ...                           ...
# 44668   49279  The Man with the Rubber Head
# 44671   49271           The Devilish Tenant
# 44675   49280              The One-Man Band
# 44678  404604                           Mom
# 44685   30840                    Robin Hood
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
highVoteCount.reset_index(inplace = True)

# %%
highVoteCount.iloc[highVoteCount.vote_average.sort_values(ascending = False).head(5).index].title
# Out:
# 14094    As I Was Moving Ahead Occasionally I Saw Brief...
# 22174                                      Planet Earth II
# 12919                                        The Civil War
# 7978                           Dilwale Dulhania Le Jayenge
# 22241                                               Cosmos
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
df.iloc[df.vote_average.sort_values(ascending = True).head(5).index].title
# Out:
# 24522                            Dance, Fools, Dance
# 37762    .hack Liminality: In the Case of Mai Minase
# 26403                                Lucrezia Borgia
# 12189                                    Joe and Max
# 20450                                 The Substitute
# Name: title, dtype: object

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
df.iloc[df.popularity.sort_values(ascending = False).head(5).index].title
# Out:
# 30330                 Minions
# 32927            Wonder Woman
# 41556    Beauty and the Beast
# 42940             Baby Driver
# 24187              Big Hero 6
# Name: title, dtype: object

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
mask1 = df.genres.str.lower().str.contains("science fiction")
mask2 = df.cast.str.lower().str.contains("bruce willis")

# %%
((df.genres.str.lower().str.contains("science fiction")) & (df.cast.str.lower().str.contains("bruce willis"))).sum()
# Out:
# 10

# %%
df_focus = df.loc[mask1 & mask2].copy()
df_focus.title
# Out:
# 31              Twelve Monkeys
# 499                      North
# 1448         The Fifth Element
# 1786                Armageddon
# 3836               Unbreakable
# 11489     The Astronaut Farmer
# 14135               Surrogates
# 19218                   Looper
# 20333    G.I. Joe: Retaliation
# 27619                     Vice
# Name: title, dtype: object

# %%
bruceInScienceFiction = df_focus.sort_values(by = "vote_average", ascending = False)
bruceInScienceFiction.title
# Out:
# 31              Twelve Monkeys
# 1448         The Fifth Element
# 3836               Unbreakable
# 19218                   Looper
# 1786                Armageddon
# 11489     The Astronaut Farmer
# 14135               Surrogates
# 20333    G.I. Joe: Retaliation
# 499                      North
# 27619                     Vice
# Name: title, dtype: object

# %%
bruceInScienceFiction = bruceInScienceFiction[["poster_path", "title","vote_average"]].copy()
bruceInScienceFiction
# Out:
#                                              poster_path  \
# 31     <img src='http://image.tmdb.org/t/p/w185//2F9K...
# 1448   <img src='http://image.tmdb.org/t/p/w185//fPtl...
# 3836   <img src='http://image.tmdb.org/t/p/w185//kXkV...
# 19218  <img src='http://image.tmdb.org/t/p/w185//sNjL...
# 1786   <img src='http://image.tmdb.org/t/p/w185//fMtO...
# 11489  <img src='http://image.tmdb.org/t/p/w185//19uG...
# 14135  <img src='http://image.tmdb.org/t/p/w185//v3Z0...
# 20333  <img src='http://image.tmdb.org/t/p/w185//3rWI...
# 499    <img src='http://image.tmdb.org/t/p/w185//qXTw...
# 27619  <img src='http://image.tmdb.org/t/p/w185//nPqN...
#
#                        title  vote_average
# 31            Twelve Monkeys          7.40
# 1448       The Fifth Element          7.30
# 3836             Unbreakable          6.90
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 11489   The Astronaut Farmer          6.20
# ...

# %%
from IPython.display import HTML
pd.options.display.max_colwidth = 200

# %%
HTML(bruceInScienceFiction.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>title</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>31</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2F9KcDGZbEdaQN5jV9ziyRZYY7u.jpg' style='height:100px;'></td>
#       <td>Twelve Monkeys</td>
#       <td>7.40</td>
#     </tr>
#     <tr>
#       <th>1448</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>The Fifth Element</td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>3836</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//kXkV3RKsSf49wbSnUerKZFMQORB.jpg' style='height:100px;'></td>
#       <td>Unbreakable</td>
#       <td>6.90</td>
#     </tr>
#     <tr>
#       <th>19218</th>
# ...

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
mask3 = df.cast.str.lower().str.contains("uma thurman")
mask4 = df.director.str.lower().str.contains("quentin tarantino")

# %%
((df.cast.str.lower().str.contains("uma thurman")) & (df.director.str.lower().str.contains("quentin tarantino"))).sum()
# Out:
# 3

# %%
df_focus2 = df.loc[mask3 & mask4].copy()
df_focus2.title
# Out:
# 291          Pulp Fiction
# 6667    Kill Bill: Vol. 1
# 7208    Kill Bill: Vol. 2
# Name: title, dtype: object

# %%
uma_thurman_by_tarantino = df_focus2.sort_values(by = "runtime", ascending = True)
uma_thurman_by_tarantino.title
# Out:
# 6667    Kill Bill: Vol. 1
# 7208    Kill Bill: Vol. 2
# 291          Pulp Fiction
# Name: title, dtype: object

# %%
uma_thurman_by_tarantino = uma_thurman_by_tarantino[["poster_path", "title","runtime"]].copy()
uma_thurman_by_tarantino
# Out:
#                                                                                             poster_path  \
# 6667  <img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'>
# 7208  <img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'>
# 291   <img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'>
#
#                   title  runtime
# 6667  Kill Bill: Vol. 1   111.00
# 7208  Kill Bill: Vol. 2   136.00
# 291        Pulp Fiction   154.00

# %%
HTML(uma_thurman_by_tarantino.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>title</th>
#       <th>runtime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6667</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>Kill Bill: Vol. 1</td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>7208</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>Kill Bill: Vol. 2</td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>291</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>Pulp Fiction</td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %% [markdown]
# - (Method 1) month method

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("movies_complete.csv", index_col = [3], parse_dates = [3])
df.head()
# Out:
#                  id                        title  \
# release_date
# 1995-10-30      862                    Toy Story
# 1995-12-15     8844                      Jumanji
# 1995-12-22    15602             Grumpier Old Men
# 1995-12-22    31357            Waiting to Exhale
# 1995-02-10    11862  Father of the Bride Part II
#
#                                                                                      tagline  \
# release_date
# 1995-10-30                                                                               NaN
# 1995-12-15                                         Roll the dice and unleash the excitement!
# 1995-12-22                              Still Yelling. Still Fighting. Still Ready for Love.
# 1995-12-22    Friends are the people who let you be yourself... and never let you forget it.
# 1995-02-10    Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#                                 genres           belongs_to_collection  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44691 entries, 1995-10-30 to 2017-06-09
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   genres                 42586 non-null  object
#  4   belongs_to_collection  4463 non-null   object
#  5   original_language      44681 non-null  object
#  6   budget_musd            8854 non-null   float64
#  7   revenue_musd           7385 non-null   float64
#  8   production_companies   33356 non-null  object
#  9   production_countries   38835 non-null  object
#  10  vote_count             44691 non-null  float64
#  11  vote_average           42077 non-null  float64
#  12  popularity             44691 non-null  float64
#  13  runtime                43179 non-null  float64
# ...

# %%
import calendar
import datetime

# %%
df.index.month
# Out:
# Float64Index([10.0, 12.0, 12.0, 12.0,  2.0, 12.0, 12.0, 12.0, 12.0, 11.0,
#               ...
#                3.0, 10.0, 10.0,  1.0,  5.0,  nan, 11.0,  8.0, 10.0,  6.0],
#              dtype='float64', name='release_date', length=44691)

# %%
df["year"] = df.index.year
df.head()
# Out:
#                  id                        title  \
# release_date
# 1995-10-30      862                    Toy Story
# 1995-12-15     8844                      Jumanji
# 1995-12-22    15602             Grumpier Old Men
# 1995-12-22    31357            Waiting to Exhale
# 1995-02-10    11862  Father of the Bride Part II
#
#                                                                                      tagline  \
# release_date
# 1995-10-30                                                                               NaN
# 1995-12-15                                         Roll the dice and unleash the excitement!
# 1995-12-22                              Still Yelling. Still Fighting. Still Ready for Love.
# 1995-12-22    Friends are the people who let you be yourself... and never let you forget it.
# 1995-02-10    Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#                                 genres           belongs_to_collection  \
# ...

# %%
mask5 = df.production_companies.str.lower().str.contains("pixar")
mask6 = ((df.year >= 2010) & (df.year <= 2015))

# %%
df_focus3 = df.loc[mask5 & mask6].copy()
df_focus3.title
# Out:
# release_date
# 2010-06-16                   Toy Story 3
# 2010-06-17                   Day & Night
# 2011-06-11                        Cars 2
# 2012-06-21                         Brave
# 2013-06-20           Monsters University
# 2013-02-12             The Blue Umbrella
# 2013-10-15          Toy Story of Terror!
# 2011-01-01                       La luna
# 2011-06-16             Hawaiian Vacation
# 2011-11-23                     Small Fry
# 2012-09-14               Partysaurus Rex
# 2012-01-01          The Legend of Mor'du
# 2014-12-02    Toy Story That Time Forgot
# 2015-06-09                    Inside Out
# 2015-11-14             The Good Dinosaur
# 2015-06-21                          Lava
# 2015-11-25           Sanjay's Super Team
# 2011-08-04                     Air Mater
# 2015-11-03           Riley's First Date?
# Name: title, dtype: object

# %%
df_focus3.sort_values(by = "revenue_musd", ascending = False).title
# Out:
# release_date
# 2010-06-16                   Toy Story 3
# 2015-06-09                    Inside Out
# 2013-06-20           Monsters University
# 2011-06-11                        Cars 2
# 2012-06-21                         Brave
# 2015-11-14             The Good Dinosaur
# 2010-06-17                   Day & Night
# 2013-02-12             The Blue Umbrella
# 2013-10-15          Toy Story of Terror!
# 2011-01-01                       La luna
# 2011-06-16             Hawaiian Vacation
# 2011-11-23                     Small Fry
# 2012-09-14               Partysaurus Rex
# 2012-01-01          The Legend of Mor'du
# 2014-12-02    Toy Story That Time Forgot
# 2015-06-21                          Lava
# 2015-11-25           Sanjay's Super Team
# 2011-08-04                     Air Mater
# 2015-11-03           Riley's First Date?
# Name: title, dtype: object

# %% [markdown]
# - (Method 2) betweeen method using parse_dates = [""] when importing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("movies_complete.csv", parse_dates = ["release_date"])
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                                                           tagline  \
# 0                                                                             NaN
# 1                                       Roll the dice and unleash the excitement!
# 2                            Still Yelling. Still Fighting. Still Ready for Love.
# 3  Friends are the people who let you be yourself... and never let you forget it.
# 4  Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#   release_date                    genres           belongs_to_collection  \
# 0   1995-10-30   Animation|Comedy|Family            Toy Story Collection
# 1   1995-12-15  Adventure|Fantasy|Family                             NaN
# ...

# %%
mask_alt1 = df.production_companies.str.lower().str.contains("pixar")
mask_alt2 = df.release_date.between("2010-01-01", "2015-12-31")

# %%
df_focus_alt = df.loc[mask_alt1 & mask_alt2].copy()
df_focus_alt.title
# Out:
# 15236                   Toy Story 3
# 16392                   Day & Night
# 17220                        Cars 2
# 18900                         Brave
# 20888           Monsters University
# 21694             The Blue Umbrella
# 21697          Toy Story of Terror!
# 22489                       La luna
# 24252             Hawaiian Vacation
# 24254                     Small Fry
# 25515               Partysaurus Rex
# 25516          The Legend of Mor'du
# 25517    Toy Story That Time Forgot
# 29957                    Inside Out
# 30388             The Good Dinosaur
# 31803                          Lava
# 34560           Sanjay's Super Team
# 40259                     Air Mater
# 40675           Riley's First Date?
# Name: title, dtype: object

# %%
df_focus_alt.sort_values(by = "revenue_musd", ascending = False).head().title
# Out:
# 15236            Toy Story 3
# 29957             Inside Out
# 20888    Monsters University
# 17220                 Cars 2
# 18900                  Brave
# Name: title, dtype: object

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
df.original_language
# Out:
# 0        en
# 1        en
# 2        en
# 3        en
# 4        en
#          ..
# 44686    fa
# 44687    tl
# 44688    en
# 44689    en
# 44690    en
# Name: original_language, Length: 44691, dtype: object

# %%
df.vote_average
# Out:
# 0       7.70
# 1       6.90
# 2       6.50
# 3       6.10
# 4       5.70
#         ...
# 44686   4.00
# 44687   9.00
# 44688   3.80
# 44689    NaN
# 44690    NaN
# Name: vote_average, Length: 44691, dtype: float64

# %%
mask7 = df.genres.str.lower().str.contains("action")
mask8 = df.genres.str.lower().str.contains("thriller")

# %% [markdown]
# mask7_and_8 = df.genres.str.lower().str.contains("action") | df.genres.str.lower().str.contains("thriller")

# %%
df_focus5 = df.loc[mask7 | mask8].copy()

# %%
mask9 = df_focus5.original_language.str.lower().str.contains("en")
mask10 = (df_focus5.vote_average >= 7.5)

# %%
df_focus6 = df_focus5.loc[mask9 & mask10].copy()

# %%
df_focus6.sort_values(by='release_date', ascending = False).head().title
# Out:
# 44490                     Descendants 2
# 43941                           Dunkirk
# 42624                 The Book of Henry
# 26273    Guardians of the Galaxy Vol. 2
# 43467                       Revengeance
# Name: title, dtype: object

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df = pd.read_csv("movies_complete.csv")
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                                                           tagline  \
# 0                                                                             NaN
# 1                                       Roll the dice and unleash the excitement!
# 2                            Still Yelling. Still Fighting. Still Ready for Love.
# 3  Friends are the people who let you be yourself... and never let you forget it.
# 4  Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#   release_date                    genres           belongs_to_collection  \
# 0   1995-10-30   Animation|Comedy|Family            Toy Story Collection
# 1   1995-12-15  Adventure|Fantasy|Family                             NaN
# ...

# %% [markdown]
# - (Method 1) Data splitting using inner join and anti join

# %%
collectionGroup = df.groupby("belongs_to_collection").revenue_musd.mean()
collectionGroup
# Out:
# belongs_to_collection
# ... Has Fallen Collection              183.39
# 00 Schneider Filmreihe                    NaN
# 08/15 Collection                          NaN
# 100 Girls Collection                      NaN
# 101 Dalmatians (Animated) Collection   215.88
#                                         ...
# Сказки Чуковского                         NaN
# Чебурашка и крокодил Гена                 NaN
# Что Творят мужчины! (Коллекция)           NaN
# 男はつらいよ シリーズ                               NaN
# 식객 시리즈                                    NaN
# Name: revenue_musd, Length: 1691, dtype: float64

# %%
df_collection = pd.merge(df, collectionGroup, how = "inner", left_on= "belongs_to_collection", right_on = "belongs_to_collection")
df_collection
# Out:
#           id                  title  \
# 0        862              Toy Story
# 1        863            Toy Story 2
# 2      10193            Toy Story 3
# 3      15602       Grumpier Old Men
# 4      11520         Grumpy Old Men
# ...      ...                    ...
# 4458   79701     Gena the Crocodile
# 4459   68637                Ducoboo
# 4460   78359  Mister Blot's Academy
# 4461  152912      Mr. Blot in Space
# 4462  182030        The Twin Swords
#
#                                                      tagline release_date  \
# 0                                                        NaN   1995-10-30
# 1                                         The toys are back!   1999-10-30
# 2                                   No toy gets left behind.   2010-06-16
# 3       Still Yelling. Still Fighting. Still Ready for Love.   1995-12-22
# 4     The best of enemies until something came between them.   1993-12-25
# ...                                                      ...          ...
# ...

# %%
df_collection.revenue_musd_x.mean()
# Out:
# 165.70819260175793

# %%
temp1 = df.merge(collectionGroup, on='belongs_to_collection', how='left', indicator=True)

# %%
temp2 = temp1.loc[temp1['_merge'] == 'left_only', 'belongs_to_collection']

# %%
anti_join = df[df['belongs_to_collection'].isin(temp2)].copy()
anti_join.head()
# Out:
#       id              title  \
# 1   8844            Jumanji
# 3  31357  Waiting to Exhale
# 5    949               Heat
# 6  11860            Sabrina
# 7  45325       Tom and Huck
#
#                                                                           tagline  \
# 1                                       Roll the dice and unleash the excitement!
# 3  Friends are the people who let you be yourself... and never let you forget it.
# 5                                                        A Los Angeles Crime Saga
# 6            You are cordially invited to the most surprising merger of the year.
# 7                                                          The Original Bad Boys.
#
#   release_date                         genres belongs_to_collection  \
# 1   1995-12-15       Adventure|Fantasy|Family                   NaN
# 3   1995-12-22           Comedy|Drama|Romance                   NaN
# 5   1995-12-15    Action|Crime|Drama|Thriller                   NaN
# ...

# %%
anti_join.revenue_musd.mean()
# Out:
# 44.7428140060955

# %% [markdown]
# - (Method 2) Having a column indicator

# %%
df["Franchise"] = df.belongs_to_collection.notna()
# notna(): Return a boolean same-sized object indicating if the values are not NA.

# %%
df.head()
# True or False to whether it's franchise or non-franchise
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                                                           tagline  \
# 0                                                                             NaN
# 1                                       Roll the dice and unleash the excitement!
# 2                            Still Yelling. Still Fighting. Still Ready for Love.
# 3  Friends are the people who let you be yourself... and never let you forget it.
# 4  Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#   release_date                    genres           belongs_to_collection  \
# 0   1995-10-30   Animation|Comedy|Family            Toy Story Collection
# 1   1995-12-15  Adventure|Fantasy|Family                             NaN
# ...

# %%
df.groupby("Franchise").revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df_collection["roi"] = round((df_collection.revenue_musd_x/df_collection.budget_musd), 2)

# %%
df_collection.roi.median()
# Out:
# 3.71

# %%
anti_join["roi"] = round((anti_join.revenue_musd/anti_join.budget_musd), 2)

# %%
anti_join.roi.median()
# Out:
# 1.62

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df_collection.budget_musd.mean()
# Out:
# 38.31984712958281

# %%
anti_join.budget_musd.mean()
# Out:
# 18.047741174779976

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df_collection.popularity.mean()
# Out:
# 6.245051188662335

# %%
anti_join.popularity.mean()
# Out:
# 2.592726062543502

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df_collection.vote_average.mean()
# Out:
# 5.956805807622504

# %%
anti_join.vote_average.mean()
# Out:
# 6.008787066287929

# %% [markdown]
# __Agg methods to put it together__

# %%
df["roi"] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby("Franchise").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean",
                            "popularity": "mean", "roi":"median", "vote_count":"mean"})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  roi  \
# Franchise
# False            18.05         44.74          6.01        2.59 1.62
# True             38.32        165.71          5.96        6.25 3.71
#
#            vote_count
# Franchise
# False           78.29
# True           412.39

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df_collection.head()
# Out:
#       id             title  \
# 0    862         Toy Story
# 1    863       Toy Story 2
# 2  10193       Toy Story 3
# 3  15602  Grumpier Old Men
# 4  11520    Grumpy Old Men
#
#                                                   tagline release_date  \
# 0                                                     NaN   1995-10-30
# 1                                      The toys are back!   1999-10-30
# 2                                No toy gets left behind.   2010-06-16
# 3    Still Yelling. Still Fighting. Still Ready for Love.   1995-12-22
# 4  The best of enemies until something came between them.   1993-12-25
#
#                     genres      belongs_to_collection original_language  \
# 0  Animation|Comedy|Family       Toy Story Collection                en
# 1  Animation|Comedy|Family       Toy Story Collection                en
# 2  Animation|Family|Comedy       Toy Story Collection                en
# 3           Romance|Comedy  Grumpy Old Men Collection                en
# ...

# %%
df_collection.groupby(["belongs_to_collection"])["title"].nunique().sort_values(ascending = False)
# Out:
# belongs_to_collection
# The Bowery Boys                               29
# Totò Collection                               27
# Zatôichi: The Blind Swordsman                 26
# The Carry On Collection                       25
# James Bond Collection                         25
#                                               ..
# The Adventures of Mickey Matson Collection     1
# Hailey Dean Mystery Collection                 1
# The 1997 Trilogy                               1
# Hard Time Collection                           1
# Flesh Gordon Collection                        1
# Name: title, Length: 1691, dtype: int64

# %%
df_collection.groupby(["belongs_to_collection"])["budget_musd"].sum().sort_values(ascending = False)
# Out:
# belongs_to_collection
# James Bond Collection                 1539.65
# Harry Potter Collection               1280.00
# Pirates of the Caribbean Collection   1250.00
# The Fast and the Furious Collection   1009.00
# X-Men Collection                       983.00
#                                         ...
# Little Bear                              0.00
# Lilla Jönsonligan Collection             0.00
# Library Wars Collection                  0.00
# Lezioni di Cioccolato Collection         0.00
# 식객 시리즈                                   0.00
# Name: budget_musd, Length: 1691, dtype: float64

# %%
df_collection.groupby(["belongs_to_collection"])["budget_musd"].mean().sort_values(ascending = False)
# Out:
# belongs_to_collection
# Tangled Collection                    260.00
# The Avengers Collection               250.00
# Pirates of the Caribbean Collection   250.00
# The Hobbit Collection                 250.00
# Man of Steel Collection               237.50
#                                        ...
# Параграф 78 - Дилогия                    NaN
# Сказки Чуковского                        NaN
# Чебурашка и крокодил Гена                NaN
# 男はつらいよ シリーズ                              NaN
# 식객 시리즈                                   NaN
# Name: budget_musd, Length: 1691, dtype: float64

# %%
df_collection.groupby(["belongs_to_collection"])["revenue_musd_x"].sum().sort_values(ascending = False)
# Out:
# belongs_to_collection
# Harry Potter Collection                7707.37
# Star Wars Collection                   7434.49
# James Bond Collection                  7106.97
# The Fast and the Furious Collection    5125.10
# Pirates of the Caribbean Collection    4521.58
#                                          ...
# Les Profs                                 0.00
# Les Mystères de l'ouest (Collection)      0.00
# Les Charlots - Saga                       0.00
# Les Boys                                  0.00
# 식객 시리즈                                    0.00
# Name: revenue_musd_x, Length: 1691, dtype: float64

# %%
df_collection.groupby(["belongs_to_collection"])["revenue_musd_x"].mean().sort_values(ascending = False)
# Out:
# belongs_to_collection
# Avatar Collection                 2787.97
# The Avengers Collection           1462.48
# Frozen Collection                 1274.22
# Finding Nemo Collection            984.45
# The Hobbit Collection              978.51
#                                     ...
# Сказки Чуковского                     NaN
# Чебурашка и крокодил Гена             NaN
# Что Творят мужчины! (Коллекция)       NaN
# 男はつらいよ シリーズ                           NaN
# 식객 시리즈                                NaN
# Name: revenue_musd_x, Length: 1691, dtype: float64

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__

# %%
df.groupby(["director"])["id"].count().sort_values(ascending = False)
# Out:
# director
# John Ford           66
# Michael Curtiz      65
# Werner Herzog       54
# Alfred Hitchcock    53
# Woody Allen         49
#                     ..
# Jason Zada           1
# Jasper James         1
# Javier Aguirre       1
# Javier Balaguer      1
# 진모영                  1
# Name: id, Length: 17349, dtype: int64

# %%
df.groupby(["director"])["revenue_musd"].sum().sort_values(ascending = False)
# Out:
# director
# Steven Spielberg   9256.62
# Peter Jackson      6528.24
# Michael Bay        6437.47
# James Cameron      5900.61
# David Yates        5334.56
#                      ...
# Héctor Olivera        0.00
# Hélène Fillières      0.00
# Héléna Klotz          0.00
# I. Robert Levy        0.00
# 진모영                   0.00
# Name: revenue_musd, Length: 17349, dtype: float64

# %% [markdown]
# ## Most Successful Actors

# %% [markdown]
# 6. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total budget__
# - __total revenue__

# %%
df = pd.read_csv("movies_complete.csv", index_col = 'id')
df.head()
# index_col = 'id' so that we can merge referring to the id.
# Out:
#                              title  \
# id
# 862                      Toy Story
# 8844                       Jumanji
# 15602             Grumpier Old Men
# 31357            Waiting to Exhale
# 11862  Father of the Bride Part II
#
#                                                                               tagline  \
# id
# 862                                                                               NaN
# 8844                                        Roll the dice and unleash the excitement!
# 15602                            Still Yelling. Still Fighting. Still Ready for Love.
# 31357  Friends are the people who let you be yourself... and never let you forget it.
# 11862  Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#       release_date                    genres           belongs_to_collection  \
# id
# 862     1995-10-30   Animation|Comedy|Family            Toy Story Collection
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44691 entries, 862 to 461257
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  44691 non-null  object
#  1   tagline                20284 non-null  object
#  2   release_date           44657 non-null  object
#  3   genres                 42586 non-null  object
#  4   belongs_to_collection  4463 non-null   object
#  5   original_language      44681 non-null  object
#  6   budget_musd            8854 non-null   float64
#  7   revenue_musd           7385 non-null   float64
#  8   production_companies   33356 non-null  object
#  9   production_countries   38835 non-null  object
#  10  vote_count             44691 non-null  float64
#  11  vote_average           42077 non-null  float64
#  12  popularity             44691 non-null  float64
#  13  runtime                43179 non-null  float64
# ...

# %%
df.cast
# Out:
# id
# 862                                    Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyru...
# 15602                                                                                                              Walter Matthau|Jack Lemmon|Ann-Margret|Sophia Loren|Daryl Hannah|Burgess Meredith|Kevin Pollak
# 31357                                                       Whitney Houston|Angela Bassett|Loretta Devine|Lela Rochon|Gregory Hines|Dennis Haysbert|Michael Beach|Mykelti Williamson|Lamont Johnson|Wesley Snipes
# ...

# %%
df2 = df.loc[:, ["title", "cast", "budget_musd", "revenue_musd", "vote_average"]]
df2.head()
# Out:
#                              title  \
# id
# 862                      Toy Story
# 8844                       Jumanji
# 15602             Grumpier Old Men
# 31357            Waiting to Exhale
# 11862  Father of the Bride Part II
#
#                                                                                                                                                                                                           cast  \
# id
# 862                                 Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 8844   Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyru...
# ...

# %%
splitted = df2['cast'].str.split('|', expand=True)
splitted.head()
# Out:
#                    0               1               2    \
# id
# 862          Tom Hanks       Tim Allen     Don Rickles
# 8844    Robin Williams   Jonathan Hyde   Kirsten Dunst
# 15602   Walter Matthau     Jack Lemmon     Ann-Margret
# 31357  Whitney Houston  Angela Bassett  Loretta Devine
# 11862     Steve Martin    Diane Keaton    Martin Short
#
#                              3               4                  5    \
# id
# 862                   Jim Varney   Wallace Shawn  John Ratzenberger
# 8844              Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# 15602               Sophia Loren    Daryl Hannah   Burgess Meredith
# 31357                Lela Rochon   Gregory Hines    Dennis Haysbert
# 11862  Kimberly Williams-Paisley  George Newbern      Kieran Culkin
#
#                     6                    7                      8    \
# id
# 862         Annie Potts          John Morris        Erik von Detten
# 8844   David Alan Grier    Patricia Clarkson         Adam Hann-Byrd
# ...

# %%
splitted.stack()
# stacked by id
# Out:
# id
# 862     0            Tom Hanks
#         1            Tim Allen
#         2          Don Rickles
#         3           Jim Varney
#         4        Wallace Shawn
#                    ...
# 227506  0     Iwan Mosschuchin
#         1    Nathalie Lissenko
#         2         Pavel Pavlov
#         3    Aleksandr Chabrov
#         4          Vera Orlova
# Length: 557703, dtype: object

# %%
splitted.stack().reset_index().head()
#level_1 = the number of actors in an id
# Out:
#     id  level_1              0
# 0  862        0      Tom Hanks
# 1  862        1      Tim Allen
# 2  862        2    Don Rickles
# 3  862        3     Jim Varney
# 4  862        4  Wallace Shawn

# %%
splitted.stack().reset_index(level=1, drop=True)
# Out:
# id
# 862               Tom Hanks
# 862               Tim Allen
# 862             Don Rickles
# 862              Jim Varney
# 862           Wallace Shawn
#                 ...
# 227506     Iwan Mosschuchin
# 227506    Nathalie Lissenko
# 227506         Pavel Pavlov
# 227506    Aleksandr Chabrov
# 227506          Vera Orlova
# Length: 557703, dtype: object

# %%
splitted = splitted.stack().reset_index(level=1, drop=True).to_frame()
splitted.head()
# Out:
#                  0
# id
# 862      Tom Hanks
# 862      Tim Allen
# 862    Don Rickles
# 862     Jim Varney
# 862  Wallace Shawn

# %%
splitted.rename(columns = {0:"actors"}, inplace = True)
splitted.head()
# Out:
#             actors
# id
# 862      Tom Hanks
# 862      Tim Allen
# 862    Don Rickles
# 862     Jim Varney
# 862  Wallace Shawn

# %%
merged = pd.merge(df2, splitted, how = "left", left_index = True, right_index = True).drop(columns = "cast")
merged.head()
# merge referring to each dataframe
# Out:
#                   title  budget_musd  revenue_musd  vote_average  \
# id
# 2                 Ariel          NaN           NaN          7.10
# 2                 Ariel          NaN           NaN          7.10
# 2                 Ariel          NaN           NaN          7.10
# 2                 Ariel          NaN           NaN          7.10
# 3   Shadows in Paradise          NaN           NaN          7.10
#
#               actors
# id
# 2        Turo Pajala
# 2   Susanna Haavisto
# 2    Matti Pellonpää
# 2       Eetu Hilkamo
# 3    Matti Pellonpää

# %%
merged.groupby(["actors"])["title"].nunique().sort_values(ascending = False)
# Out:
# actors
# Bess Flowers         239
# Christopher Lee      148
# John Wayne           125
# Samuel L. Jackson    122
# John Carradine       109
#                     ...
# James Saunders         1
# James Saxenmeyer       1
# James Saxon            1
# James Scales           1
# 조병만                    1
# Name: title, Length: 201501, dtype: int64

# %%
merged.groupby(["actors"])["revenue_musd"].sum().sort_values(ascending = False)
# Out:
# actors
# Stan Lee            19414.96
# Samuel L. Jackson   17109.62
# Warwick Davis       13256.03
# Frank Welker        13044.15
# John Ratzenberger   12596.13
#                       ...
# Janine Perreau          0.00
# Janine Reynaud          0.00
# Janine Souchon          0.00
# Janine Venable          0.00
# 조병만                     0.00
# Name: revenue_musd, Length: 201501, dtype: float64

# %%
merged.groupby(["actors"])["budget_musd"].sum().sort_values(ascending = False).head(70)
# Out:
# actors
# Stan Lee            4889.50
# Samuel L. Jackson   4855.67
# Johnny Depp         3840.27
# Morgan Freeman      3331.00
# Bruce Willis        3304.45
#                       ...
# Andy Serkis         2131.00
# Patrick Stewart     2129.30
# Simon Pegg          2128.00
# Vin Diesel          2110.00
# Chris Hemsworth     2109.00
# Name: budget_musd, Length: 70, dtype: float64
